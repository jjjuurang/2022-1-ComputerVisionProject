# %% [markdown]
# #**ResNet Training (MNIST)**

# %% [markdown]
# ###**1. Import Library & Define Resnet model**

# %%
import torch
import torch.nn as nn

from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os
import torchvision
import torchvision.transforms as transforms


class Conv2dAuto(nn.Conv2d):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.padding =  (self.kernel_size[0] // 2, self.kernel_size[1] // 2) # dynamic add padding based on the kernel_size
        

conv3x3 = partial(Conv2dAuto, kernel_size=3, bias=False)


class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.in_channels, self.out_channels =  in_channels, out_channels
        self.blocks = nn.Identity()
        self.shortcut = nn.Identity()   
    
    def forward(self, x):
        residual = x
        if self.should_apply_shortcut: residual = self.shortcut(x)
        x = self.blocks(x)
        x += residual
        return x
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.out_channels
    


class ResNetResidualBlock(ResidualBlock):
    def __init__(self, in_channels, out_channels, expansion=1, downsampling=1, conv=conv3x3, *args, **kwargs):
        super().__init__(in_channels, out_channels)
        self.expansion, self.downsampling, self.conv = expansion, downsampling, conv
        self.shortcut = nn.Sequential(OrderedDict(
        {
            'conv' : nn.Conv2d(self.in_channels, self.expanded_channels, kernel_size=1,
                      stride=self.downsampling, bias=False),
            'bn' : nn.BatchNorm2d(self.expanded_channels)
            
        })) if self.should_apply_shortcut else None
        
        
    @property
    def expanded_channels(self):
        return self.out_channels * self.expansion
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.expanded_channels

def conv_bn(in_channels, out_channels, conv, *args, **kwargs):
    return nn.Sequential(OrderedDict({'conv': conv(in_channels, out_channels, *args, **kwargs), 
                          'bn': nn.BatchNorm2d(out_channels) }))

class ResNetBasicBlock(ResNetResidualBlock):
    expansion = 1
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, *args, **kwargs)
        self.blocks = nn.Sequential(
            conv_bn(self.in_channels, self.out_channels, conv=self.conv, bias=False, stride=self.downsampling),
            activation(),
            conv_bn(self.out_channels, self.expanded_channels, conv=self.conv, bias=False),
        )
        
class ResNetBottleNeckBlock(ResNetResidualBlock):
    expansion = 4
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, expansion=4, *args, **kwargs)
        self.blocks = nn.Sequential(
           conv_bn(self.in_channels, self.out_channels, self.conv, kernel_size=1),
             activation(),
             conv_bn(self.out_channels, self.out_channels, self.conv, kernel_size=3, stride=self.downsampling),
             activation(),
             conv_bn(self.out_channels, self.expanded_channels, self.conv, kernel_size=1),
        )
        
class ResNetLayer(nn.Module):
    def __init__(self, in_channels, out_channels, block=ResNetBasicBlock, n=1, *args, **kwargs):
        super().__init__()
        # 'We perform downsampling directly by convolutional layers that have a stride of 2.'
        downsampling = 2 if in_channels != out_channels else 1
        
        self.blocks = nn.Sequential(
            block(in_channels , out_channels, *args, **kwargs, downsampling=downsampling),
            *[block(out_channels * block.expansion, 
                    out_channels, downsampling=1, *args, **kwargs) for _ in range(n - 1)]
        )

    def forward(self, x):
        x = self.blocks(x)
        return x
    
class ResNetEncoder(nn.Module):
    """
    ResNet encoder composed by increasing different layers with increasing features.
    """
    def __init__(self, in_channels=3, blocks_sizes=[64, 128, 256, 512], deepths=[2,2,2,2], 
                 activation=nn.ReLU, block=ResNetBasicBlock, *args,**kwargs):
        super().__init__()
        
        self.blocks_sizes = blocks_sizes
        
        self.gate = nn.Sequential(
            nn.Conv2d(in_channels, self.blocks_sizes[0], kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(self.blocks_sizes[0]),
            activation(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        
        self.in_out_block_sizes = list(zip(blocks_sizes, blocks_sizes[1:]))
        self.blocks = nn.ModuleList([ 
            ResNetLayer(blocks_sizes[0], blocks_sizes[0], n=deepths[0], activation=activation, 
                        block=block,  *args, **kwargs),
            *[ResNetLayer(in_channels * block.expansion, 
                          out_channels, n=n, activation=activation, 
                          block=block, *args, **kwargs) 
              for (in_channels, out_channels), n in zip(self.in_out_block_sizes, deepths[1:])]       
        ])
        
        
    def forward(self, x):
        x = self.gate(x)
        for block in self.blocks:
            x = block(x)
        return x
    

class ResnetDecoder(nn.Module):
    """
    This class represents the tail of ResNet. It performs a global pooling and maps the output to the
    correct class by using a fully connected layer.
    """
    def __init__(self, in_features, n_classes):
        super().__init__()
        self.avg = nn.AdaptiveAvgPool2d((1, 1))
        self.decoder = nn.Linear(in_features, n_classes)

    def forward(self, x):
        x = self.avg(x)
        x = x.view(x.size(0), -1)
        x = self.decoder(x)
        return x
    
class ResNet(nn.Module):
    
    def __init__(self, in_channels, n_classes, *args, **kwargs):
        super().__init__()
        self.encoder = ResNetEncoder(in_channels, *args, **kwargs)
        self.decoder = ResnetDecoder(self.encoder.blocks[-1].blocks[-1].expanded_channels, n_classes)
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
def resnet18(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[2, 2, 2, 2])

def resnet34(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[3, 4, 6, 3])

def resnet50(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 6, 3])

def resnet101(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 23, 3])

def resnet152(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 8, 36, 3])

# %% [markdown]
# ###**2. Download MNIST**

# %%
#Download MNIST DATASET

transform_train = transforms.Compose([
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ###**3. CUDA setting & Define Train,Test function**

# %%
#gpu setting & define Training function

device = 'cuda'

net = resnet34(1,10)           #resnet152 선언
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet50_mnist.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)
    total_accuracy = 100. * correct / total;

    return total_accuracy , train_loss


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)
    total_accuracy = 100. * correct / total;
    test_loss = loss / total

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

    return total_accuracy , test_loss

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# ###**4. Run Training & Save log**

# %%
# for epoch in range(0, 200):
log_train_total_accuracy =[]
log_train_total_loss = []
log_test_total_accuracy =[]
log_test_total_loss =[]


for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train_total_accuracy, train_total_loss = train(epoch)
    test_total_accuracy, test_total_loss = test(epoch)
    log_train_total_accuracy.append(train_total_accuracy)
    log_train_total_loss.append(train_total_loss)
    log_test_total_accuracy.append(test_total_accuracy)
    log_test_total_loss.append(test_total_loss)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.1015625
# Current benign train loss: 2.89477276802063
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.8269563317298889
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.6989789605140686
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1873369961977005
#
# Current batch: 400
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.25239989161491394
#
# Total benign train accuarcy: 78.01166666666667
# Total benign train loss: 624.4348189420998
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 93.28
# Test average loss: 0.002115692912787199
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1942485123872757
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09711087495088577
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.038512974977493286
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04259910807013512
#
# Current batch: 400
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.15772755444049835
#
# Total benign train accuarcy: 96.14333333333333
# Total benign train loss: 60.4641037825495
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 97.39
# Test average loss: 0.0008286458055488766
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14939886331558228
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.027975648641586304
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.0765715092420578
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.19296549260616302
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.014024553820490837
#
# Total benign train accuarcy: 97.69333333333333
# Total benign train loss: 34.33065954828635
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 97.71
# Test average loss: 0.0006917651323601604
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03658188134431839
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.01639713905751705
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.007986119017004967
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05515806004405022
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03191794082522392
#
# Total benign train accuarcy: 98.21333333333334
# Total benign train loss: 26.570432472974062
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 98.72
# Test average loss: 0.0003835667415580247
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03555484116077423
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10796220600605011
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0530821792781353
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03174830973148346
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03340381756424904
#
# Total benign train accuarcy: 98.63333333333334
# Total benign train loss: 20.836264204466715
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 98.61
# Test average loss: 0.0004324174053792376
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.01177915558218956
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.006382815074175596
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0171345267444849
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05884867534041405
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.02116617187857628
#
# Total benign train accuarcy: 98.745
# Total benign train loss: 18.543388870893978
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 98.71
# Test average loss: 0.00036396897021622864
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08704216033220291
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003361787647008896
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.028614608570933342
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.021482275798916817
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04855801537632942
#
# Total benign train accuarcy: 98.79166666666667
# Total benign train loss: 17.257817531586625
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 98.24
# Test average loss: 0.0005418438930297271
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.026568343862891197
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.029880886897444725
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.020337555557489395
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.014339277520775795
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.02546118199825287
#
# Total benign train accuarcy: 98.85833333333333
# Total benign train loss: 16.104466320713982
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 98.67
# Test average loss: 0.00042663055844313933
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.017678404226899147
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0063042789697647095
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004600887652486563
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10445847362279892
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.012922464869916439
#
# Total benign train accuarcy: 99.10666666666667
# Total benign train loss: 13.481931797519792
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 98.36
# Test average loss: 0.0005230600738083013
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.019143611192703247
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008773960871621966
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.030304668471217155
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.02037806250154972
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.009970644488930702
#
# Total benign train accuarcy: 99.09666666666666
# Total benign train loss: 12.40773073292803
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 98.85
# Test average loss: 0.0003619319701087079
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0029744310304522514
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00397101603448391
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.039703089743852615
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.026473065838217735
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.014538148418068886
#
# Total benign train accuarcy: 99.17333333333333
# Total benign train loss: 11.952114354236983
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 98.5
# Test average loss: 0.00044662405901763123
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0025584292598068714
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.009961243718862534
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.04870330169796944
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008015126222744584
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0079848263412714
#
# Total benign train accuarcy: 99.12166666666667
# Total benign train loss: 12.295909020118415
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 98.0
# Test average loss: 0.0006561206465994473
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.01885668747127056
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002935522934421897
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.017071250826120377
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002306249225512147
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.013299142941832542
#
# Total benign train accuarcy: 99.23166666666667
# Total benign train loss: 11.120920368877705
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 98.85
# Test average loss: 0.0003362044808185601
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0033510057255625725
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09203381091356277
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03270570933818817
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.020221421495079994
#
# Current batch: 400
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.03575658053159714
#
# Total benign train accuarcy: 99.22333333333333
# Total benign train loss: 11.042758773313835
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 98.74
# Test average loss: 0.0004387067855903297
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.02625678852200508
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.00915208924561739
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0043913801200687885
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.017941420897841454
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0017000206280499697
#
# Total benign train accuarcy: 99.265
# Total benign train loss: 10.428463919088244
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 98.65
# Test average loss: 0.0004099230477040692
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.005878161173313856
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.01619822159409523
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.028614122420549393
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.012493561953306198
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004896809346973896
#
# Total benign train accuarcy: 99.35166666666667
# Total benign train loss: 9.413061404338805
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 98.77
# Test average loss: 0.00037053672669280785
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.008515234105288982
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004716495517641306
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.013815322890877724
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.011984890326857567
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002092216396704316
#
# Total benign train accuarcy: 99.23166666666667
# Total benign train loss: 10.84210952668218
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 98.7
# Test average loss: 0.0003968304571833869
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.01790834218263626
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003354859072715044
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.018198231235146523
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.01470993459224701
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.010635148733854294
#
# Total benign train accuarcy: 99.39666666666666
# Total benign train loss: 8.897027703584172
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 98.78
# Test average loss: 0.00040849311602651143
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.007849986664950848
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.02981935255229473
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05250855162739754
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0033225335646420717
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05896313861012459
#
# Total benign train accuarcy: 99.28166666666667
# Total benign train loss: 10.313179127755575
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 98.64
# Test average loss: 0.0004073758109472692
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03028986230492592
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004657179117202759
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003470729338005185
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.013628728687763214
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.006364923436194658
#
# Total benign train accuarcy: 99.36333333333333
# Total benign train loss: 9.164297751209233
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 98.55
# Test average loss: 0.0004639747631139471
# Model Saved!

# %% [markdown]
# ###**5. Plotting Train Accuracy & Loss**

# %%
epoch =[]

for i , loss in enumerate(log_test_total_loss):
  epoch.append(i+1)

import matplotlib.pyplot as plt

plt.title('log_train_accuracy')
plt.plot(epoch , log_train_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('train_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_train_loss')
plt.plot(epoch , log_train_total_loss)
plt.xlabel('epoch')
plt.ylabel('train_loss')
plt.show()

# %% [markdown]
# ###**6. Plotting Test Accuracy & Loss**

# %%
import matplotlib.pyplot as plt

plt.title('log_test_accuracy')
plt.plot(epoch , log_test_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('test_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_test_loss')
plt.plot(epoch , log_test_total_loss)
plt.xlabel('epoch')
plt.ylabel('test_loss')
plt.show()

# %% [markdown]
# ###**7. Print Result**

# %%
print(log_train_total_accuracy)
print(log_train_total_loss) 
print(log_test_total_accuracy)
print(log_test_total_loss)
# Out:
# [78.01166666666667, 96.14333333333333, 97.69333333333333, 98.21333333333334, 98.63333333333334, 98.745, 98.79166666666667, 98.85833333333333, 99.10666666666667, 99.09666666666666, 99.17333333333333, 99.12166666666667, 99.23166666666667, 99.22333333333333, 99.265, 99.35166666666667, 99.23166666666667, 99.39666666666666, 99.28166666666667, 99.36333333333333]
# [624.4348189420998, 60.4641037825495, 34.33065954828635, 26.570432472974062, 20.836264204466715, 18.543388870893978, 17.257817531586625, 16.104466320713982, 13.481931797519792, 12.40773073292803, 11.952114354236983, 12.295909020118415, 11.120920368877705, 11.042758773313835, 10.428463919088244, 9.413061404338805, 10.84210952668218, 8.897027703584172, 10.313179127755575, 9.164297751209233]
# [93.28, 97.39, 97.71, 98.72, 98.61, 98.71, 98.24, 98.67, 98.36, 98.85, 98.5, 98.0, 98.85, 98.74, 98.65, 98.77, 98.7, 98.78, 98.64, 98.55]
# [0.002115692912787199, 0.0008286458055488766, 0.0006917651323601604, 0.0003835667415580247, 0.0004324174053792376, 0.00036396897021622864, 0.0005418438930297271, 0.00042663055844313933, 0.0005230600738083013, 0.0003619319701087079, 0.00044662405901763123, 0.0006561206465994473, 0.0003362044808185601, 0.0004387067855903297, 0.0004099230477040692, 0.00037053672669280785, 0.0003968304571833869, 0.00040849311602651143, 0.0004073758109472692, 0.0004639747631139471]

# %% [markdown]
# ###**8. Model Summary**

# %%
from torchsummary import summary

model = resnet50(1, 10)
summary(model.cuda(), (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 14, 14]           3,136
#        BatchNorm2d-2           [-1, 64, 14, 14]             128
#               ReLU-3           [-1, 64, 14, 14]               0
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#             Conv2d-5            [-1, 256, 7, 7]          16,384
#        BatchNorm2d-6            [-1, 256, 7, 7]             512
#         Conv2dAuto-7             [-1, 64, 7, 7]           4,096
#        BatchNorm2d-8             [-1, 64, 7, 7]             128
#               ReLU-9             [-1, 64, 7, 7]               0
#        Conv2dAuto-10             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-11             [-1, 64, 7, 7]             128
#              ReLU-12             [-1, 64, 7, 7]               0
#        Conv2dAuto-13            [-1, 256, 7, 7]          16,384
#       BatchNorm2d-14            [-1, 256, 7, 7]             512
# ResNetBottleNeckBlock-15            [-1, 256, 7, 7]               0
#        Conv2dAuto-16             [-1, 64, 7, 7]          16,384
#       BatchNorm2d-17             [-1, 64, 7, 7]             128
#              ReLU-18             [-1, 64, 7, 7]               0
#        Conv2dAuto-19             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-20             [-1, 64, 7, 7]             128
#              ReLU-21             [-1, 64, 7, 7]               0
#        Conv2dAuto-22            [-1, 256, 7, 7]          16,384
#       BatchNorm2d-23            [-1, 256, 7, 7]             512
# ResNetBottleNeckBlock-24            [-1, 256, 7, 7]               0
#        Conv2dAuto-25             [-1, 64, 7, 7]          16,384
#       BatchNorm2d-26             [-1, 64, 7, 7]             128
#              ReLU-27             [-1, 64, 7, 7]               0
#        Conv2dAuto-28             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-29             [-1, 64, 7, 7]             128
#              ReLU-30             [-1, 64, 7, 7]               0
#        Conv2dAuto-31            [-1, 256, 7, 7]          16,384
#       BatchNorm2d-32            [-1, 256, 7, 7]             512
# ResNetBottleNeckBlock-33            [-1, 256, 7, 7]               0
#       ResNetLayer-34            [-1, 256, 7, 7]               0
#            Conv2d-35            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-36            [-1, 512, 4, 4]           1,024
#        Conv2dAuto-37            [-1, 128, 7, 7]          32,768
#       BatchNorm2d-38            [-1, 128, 7, 7]             256
#              ReLU-39            [-1, 128, 7, 7]               0
#        Conv2dAuto-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#        Conv2dAuto-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-45            [-1, 512, 4, 4]               0
#        Conv2dAuto-46            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-47            [-1, 128, 4, 4]             256
#              ReLU-48            [-1, 128, 4, 4]               0
#        Conv2dAuto-49            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#        Conv2dAuto-52            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-53            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-54            [-1, 512, 4, 4]               0
#        Conv2dAuto-55            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 128, 4, 4]             256
#              ReLU-57            [-1, 128, 4, 4]               0
#        Conv2dAuto-58            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-59            [-1, 128, 4, 4]             256
#              ReLU-60            [-1, 128, 4, 4]               0
#        Conv2dAuto-61            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-62            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-63            [-1, 512, 4, 4]               0
#        Conv2dAuto-64            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-65            [-1, 128, 4, 4]             256
#              ReLU-66            [-1, 128, 4, 4]               0
#        Conv2dAuto-67            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-68            [-1, 128, 4, 4]             256
#              ReLU-69            [-1, 128, 4, 4]               0
#        Conv2dAuto-70            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-71            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-72            [-1, 512, 4, 4]               0
#       ResNetLayer-73            [-1, 512, 4, 4]               0
#            Conv2d-74           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-75           [-1, 1024, 2, 2]           2,048
#        Conv2dAuto-76            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-77            [-1, 256, 4, 4]             512
#              ReLU-78            [-1, 256, 4, 4]               0
#        Conv2dAuto-79            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-80            [-1, 256, 2, 2]             512
#              ReLU-81            [-1, 256, 2, 2]               0
#        Conv2dAuto-82           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-83           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-84           [-1, 1024, 2, 2]               0
#        Conv2dAuto-85            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-86            [-1, 256, 2, 2]             512
#              ReLU-87            [-1, 256, 2, 2]               0
#        Conv2dAuto-88            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-89            [-1, 256, 2, 2]             512
#              ReLU-90            [-1, 256, 2, 2]               0
#        Conv2dAuto-91           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-92           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-93           [-1, 1024, 2, 2]               0
#        Conv2dAuto-94            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#        Conv2dAuto-97            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-98            [-1, 256, 2, 2]             512
#              ReLU-99            [-1, 256, 2, 2]               0
#       Conv2dAuto-100           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-101           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-102           [-1, 1024, 2, 2]               0
#       Conv2dAuto-103            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-104            [-1, 256, 2, 2]             512
#             ReLU-105            [-1, 256, 2, 2]               0
#       Conv2dAuto-106            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-107            [-1, 256, 2, 2]             512
#             ReLU-108            [-1, 256, 2, 2]               0
#       Conv2dAuto-109           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-110           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-111           [-1, 1024, 2, 2]               0
#       Conv2dAuto-112            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-113            [-1, 256, 2, 2]             512
#             ReLU-114            [-1, 256, 2, 2]               0
#       Conv2dAuto-115            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-116            [-1, 256, 2, 2]             512
#             ReLU-117            [-1, 256, 2, 2]               0
#       Conv2dAuto-118           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-119           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-120           [-1, 1024, 2, 2]               0
#       Conv2dAuto-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#       Conv2dAuto-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#       Conv2dAuto-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-129           [-1, 1024, 2, 2]               0
#      ResNetLayer-130           [-1, 1024, 2, 2]               0
#           Conv2d-131           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-132           [-1, 2048, 1, 1]           4,096
#       Conv2dAuto-133            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-134            [-1, 512, 2, 2]           1,024
#             ReLU-135            [-1, 512, 2, 2]               0
#       Conv2dAuto-136            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-137            [-1, 512, 1, 1]           1,024
#             ReLU-138            [-1, 512, 1, 1]               0
#       Conv2dAuto-139           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-140           [-1, 2048, 1, 1]           4,096
# ResNetBottleNeckBlock-141           [-1, 2048, 1, 1]               0
#       Conv2dAuto-142            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-143            [-1, 512, 1, 1]           1,024
#             ReLU-144            [-1, 512, 1, 1]               0
#       Conv2dAuto-145            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-146            [-1, 512, 1, 1]           1,024
#             ReLU-147            [-1, 512, 1, 1]               0
#       Conv2dAuto-148           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-149           [-1, 2048, 1, 1]           4,096
# ResNetBottleNeckBlock-150           [-1, 2048, 1, 1]               0
#       Conv2dAuto-151            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-152            [-1, 512, 1, 1]           1,024
#             ReLU-153            [-1, 512, 1, 1]               0
#       Conv2dAuto-154            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-155            [-1, 512, 1, 1]           1,024
#             ReLU-156            [-1, 512, 1, 1]               0
#       Conv2dAuto-157           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-158           [-1, 2048, 1, 1]           4,096
# ResNetBottleNeckBlock-159           [-1, 2048, 1, 1]               0
#      ResNetLayer-160           [-1, 2048, 1, 1]               0
#    ResNetEncoder-161           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-162           [-1, 2048, 1, 1]               0
#           Linear-163                   [-1, 10]          20,490
#    ResnetDecoder-164                   [-1, 10]               0
# ================================================================
# Total params: 23,522,250
# Trainable params: 23,522,250
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 4.63
# Params size (MB): 89.73
# Estimated Total Size (MB): 94.36
# ----------------------------------------------------------------
