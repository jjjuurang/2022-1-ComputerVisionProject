# %% [markdown]
# #**ResNet Training (MNIST)**

# %% [markdown]
# ###**1. Import Library & Define Resnet model**

# %%
import torch
import torch.nn as nn

from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os
import torchvision
import torchvision.transforms as transforms


class Conv2dAuto(nn.Conv2d):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.padding =  (self.kernel_size[0] // 2, self.kernel_size[1] // 2) # dynamic add padding based on the kernel_size
        

conv3x3 = partial(Conv2dAuto, kernel_size=3, bias=False)


class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.in_channels, self.out_channels =  in_channels, out_channels
        self.blocks = nn.Identity()
        self.shortcut = nn.Identity()   
    
    def forward(self, x):
        residual = x
        if self.should_apply_shortcut: residual = self.shortcut(x)
        x = self.blocks(x)
        x += residual
        return x
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.out_channels
    


class ResNetResidualBlock(ResidualBlock):
    def __init__(self, in_channels, out_channels, expansion=1, downsampling=1, conv=conv3x3, *args, **kwargs):
        super().__init__(in_channels, out_channels)
        self.expansion, self.downsampling, self.conv = expansion, downsampling, conv
        self.shortcut = nn.Sequential(OrderedDict(
        {
            'conv' : nn.Conv2d(self.in_channels, self.expanded_channels, kernel_size=1,
                      stride=self.downsampling, bias=False),
            'bn' : nn.BatchNorm2d(self.expanded_channels)
            
        })) if self.should_apply_shortcut else None
        
        
    @property
    def expanded_channels(self):
        return self.out_channels * self.expansion
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.expanded_channels

def conv_bn(in_channels, out_channels, conv, *args, **kwargs):
    return nn.Sequential(OrderedDict({'conv': conv(in_channels, out_channels, *args, **kwargs), 
                          'bn': nn.BatchNorm2d(out_channels) }))

class ResNetBasicBlock(ResNetResidualBlock):
    expansion = 1
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, *args, **kwargs)
        self.blocks = nn.Sequential(
            conv_bn(self.in_channels, self.out_channels, conv=self.conv, bias=False, stride=self.downsampling),
            activation(),
            conv_bn(self.out_channels, self.expanded_channels, conv=self.conv, bias=False),
        )
        
class ResNetBottleNeckBlock(ResNetResidualBlock):
    expansion = 4
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, expansion=4, *args, **kwargs)
        self.blocks = nn.Sequential(
           conv_bn(self.in_channels, self.out_channels, self.conv, kernel_size=1),
             activation(),
             conv_bn(self.out_channels, self.out_channels, self.conv, kernel_size=3, stride=self.downsampling),
             activation(),
             conv_bn(self.out_channels, self.expanded_channels, self.conv, kernel_size=1),
        )
        
class ResNetLayer(nn.Module):
    def __init__(self, in_channels, out_channels, block=ResNetBasicBlock, n=1, *args, **kwargs):
        super().__init__()
        # 'We perform downsampling directly by convolutional layers that have a stride of 2.'
        downsampling = 2 if in_channels != out_channels else 1
        
        self.blocks = nn.Sequential(
            block(in_channels , out_channels, *args, **kwargs, downsampling=downsampling),
            *[block(out_channels * block.expansion, 
                    out_channels, downsampling=1, *args, **kwargs) for _ in range(n - 1)]
        )

    def forward(self, x):
        x = self.blocks(x)
        return x
    
class ResNetEncoder(nn.Module):
    """
    ResNet encoder composed by increasing different layers with increasing features.
    """
    def __init__(self, in_channels=3, blocks_sizes=[64, 128, 256, 512], deepths=[2,2,2,2], 
                 activation=nn.ReLU, block=ResNetBasicBlock, *args,**kwargs):
        super().__init__()
        
        self.blocks_sizes = blocks_sizes
        
        self.gate = nn.Sequential(
            nn.Conv2d(in_channels, self.blocks_sizes[0], kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(self.blocks_sizes[0]),
            activation(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        
        self.in_out_block_sizes = list(zip(blocks_sizes, blocks_sizes[1:]))
        self.blocks = nn.ModuleList([ 
            ResNetLayer(blocks_sizes[0], blocks_sizes[0], n=deepths[0], activation=activation, 
                        block=block,  *args, **kwargs),
            *[ResNetLayer(in_channels * block.expansion, 
                          out_channels, n=n, activation=activation, 
                          block=block, *args, **kwargs) 
              for (in_channels, out_channels), n in zip(self.in_out_block_sizes, deepths[1:])]       
        ])
        
        
    def forward(self, x):
        x = self.gate(x)
        for block in self.blocks:
            x = block(x)
        return x
    

class ResnetDecoder(nn.Module):
    """
    This class represents the tail of ResNet. It performs a global pooling and maps the output to the
    correct class by using a fully connected layer.
    """
    def __init__(self, in_features, n_classes):
        super().__init__()
        self.avg = nn.AdaptiveAvgPool2d((1, 1))
        self.decoder = nn.Linear(in_features, n_classes)

    def forward(self, x):
        x = self.avg(x)
        x = x.view(x.size(0), -1)
        x = self.decoder(x)
        return x
    
class ResNet(nn.Module):
    
    def __init__(self, in_channels, n_classes, *args, **kwargs):
        super().__init__()
        self.encoder = ResNetEncoder(in_channels, *args, **kwargs)
        self.decoder = ResnetDecoder(self.encoder.blocks[-1].blocks[-1].expanded_channels, n_classes)
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
def resnet18(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[2, 2, 2, 2])

def resnet34(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[3, 4, 6, 3])

def resnet50(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 6, 3])

def resnet101(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 23, 3])

def resnet152(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 8, 36, 3])

# %% [markdown]
# ###**2. Download MNIST**

# %%
#Download MNIST DATASET

transform_train = transforms.Compose([
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ###**3. CUDA setting & Define Train,Test function**

# %%
#gpu setting & define Training function

device = 'cuda'

net = resnet18(1,10)           #resnet152 선언
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_mnist.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)
    total_accuracy = 100. * correct / total;

    return total_accuracy , train_loss


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)
    total_accuracy = 100. * correct / total;
    test_loss = loss / total

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

    return total_accuracy , test_loss

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# ###**4. Run Training & Save log**

# %%
# for epoch in range(0, 200):
log_train_total_accuracy =[]
log_train_total_loss = []
log_test_total_accuracy =[]
log_test_total_loss =[]


for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train_total_accuracy, train_total_loss = train(epoch)
    test_total_accuracy, test_total_loss = test(epoch)
    log_train_total_accuracy.append(train_total_accuracy)
    log_train_total_loss.append(train_total_loss)
    log_test_total_accuracy.append(test_total_accuracy)
    log_test_total_loss.append(test_total_loss)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.09375
# Current benign train loss: 2.876704692840576
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.27382975816726685
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09194359183311462
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.07643476873636246
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.08302552998065948
#
# Total benign train accuarcy: 92.19
# Total benign train loss: 225.69880310632288
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 97.82
# Test average loss: 0.0007274644062039442
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11022499948740005
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.12345384061336517
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07442949712276459
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.06858628243207932
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03289387375116348
#
# Total benign train accuarcy: 97.8
# Total benign train loss: 33.42051624157466
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 97.93
# Test average loss: 0.0006357198457466438
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.06129607558250427
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.021535536274313927
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.025751972571015358
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.011157982982695103
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.09512867033481598
#
# Total benign train accuarcy: 98.38666666666667
# Total benign train loss: 23.909754170221277
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 98.87
# Test average loss: 0.0003572089217195753
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.02370893396437168
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.016982899978756905
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05801800265908241
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05546706169843674
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.015826594084501266
#
# Total benign train accuarcy: 98.74
# Total benign train loss: 18.83605555142276
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 98.36
# Test average loss: 0.00050798283690674
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.013453995808959007
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.009529413655400276
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.010276641696691513
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.006523340009152889
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06070719659328461
#
# Total benign train accuarcy: 98.95333333333333
# Total benign train loss: 15.825359959737398
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 99.1
# Test average loss: 0.00029860753240936903
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06562210619449615
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.010134483687579632
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03628595545887947
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.020268933847546577
#
# Current batch: 400
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05457840859889984
#
# Total benign train accuarcy: 99.11166666666666
# Total benign train loss: 13.026846299588215
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 98.86
# Test average loss: 0.00035752226608165073
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.036655493080616
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03056284412741661
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.008217084221541882
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.011432650499045849
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03654753416776657
#
# Total benign train accuarcy: 99.17
# Total benign train loss: 11.568893547257176
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 98.92
# Test average loss: 0.00031576446112958364
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0373368002474308
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.02492678165435791
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08708903938531876
#
# Current batch: 300
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.10591215640306473
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.019901631399989128
#
# Total benign train accuarcy: 99.19833333333334
# Total benign train loss: 11.50420736981323
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 99.07
# Test average loss: 0.0003228016897031921
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.05714905261993408
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.006127710919827223
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003010542131960392
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.013957541435956955
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.007591691799461842
#
# Total benign train accuarcy: 99.25833333333334
# Total benign train loss: 10.444432824850082
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 98.75
# Test average loss: 0.0003788476303321659
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.030789334326982498
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004886736162006855
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.006578683853149414
#
# Current batch: 300
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05493234097957611
#
# Current batch: 400
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09475824236869812
#
# Total benign train accuarcy: 99.26833333333333
# Total benign train loss: 10.305908223206643
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 98.96
# Test average loss: 0.0003144883289314748
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.008104123175144196
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00476089958101511
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03401391580700874
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.016788436099886894
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00657271733507514
#
# Total benign train accuarcy: 99.275
# Total benign train loss: 10.0787859694683
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 98.99
# Test average loss: 0.00033057121897436446
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.010713566094636917
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.006539667025208473
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.007161599583923817
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0014632034581154585
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.010254699736833572
#
# Total benign train accuarcy: 99.32666666666667
# Total benign train loss: 9.607659788918681
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 98.83
# Test average loss: 0.0003228795153947431
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002613728167489171
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.009699491783976555
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03532402589917183
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.013683951459825039
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0018283175304532051
#
# Total benign train accuarcy: 99.39666666666666
# Total benign train loss: 8.832625389739405
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 98.99
# Test average loss: 0.0003427324383355881
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.015703128650784492
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.008087457157671452
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0036870434414595366
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.018989378586411476
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03841014206409454
#
# Total benign train accuarcy: 99.38666666666667
# Total benign train loss: 8.724685507535469
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 98.8
# Test average loss: 0.0004302579949820938
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03205385059118271
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.017241772264242172
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.008848225697875023
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.011947561986744404
#
# Current batch: 400
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03849908336997032
#
# Total benign train accuarcy: 99.38833333333334
# Total benign train loss: 9.07043096923735
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 99.09
# Test average loss: 0.0002818873451447871
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.011658350005745888
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003176657948642969
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003763009561225772
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00755350524559617
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0012665013782680035
#
# Total benign train accuarcy: 99.505
# Total benign train loss: 7.275066576490644
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 98.64
# Test average loss: 0.0004232305781079049
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0018428063485771418
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.005868148058652878
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.009206131100654602
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.008798913098871708
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.015042062848806381
#
# Total benign train accuarcy: 99.32666666666667
# Total benign train loss: 9.390798871289007
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 98.93
# Test average loss: 0.0003351247566941311
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.025200944393873215
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002266234252601862
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.014834212139248848
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0026943711563944817
#
# Current batch: 400
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.01688211038708687
#
# Total benign train accuarcy: 99.47333333333333
# Total benign train loss: 7.815654943260597
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 98.33
# Test average loss: 0.0005688065864436794
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.040919944643974304
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0047157383523881435
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.009050356224179268
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.01109242532402277
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.01384699810296297
#
# Total benign train accuarcy: 99.47833333333334
# Total benign train loss: 7.717979227832984
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 98.72
# Test average loss: 0.00041005924087658056
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.014595736749470234
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05095752701163292
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0031768707558512688
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.014528000727295876
#
# Current batch: 400
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002438157796859741
#
# Total benign train accuarcy: 99.40333333333334
# Total benign train loss: 8.203844760952052
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 98.69
# Test average loss: 0.0004107659961387981
# Model Saved!

# %% [markdown]
# ###**5. Plotting Train Accuracy & Loss**

# %%
epoch =[]

for i , loss in enumerate(log_test_total_loss):
  epoch.append(i+1)

import matplotlib.pyplot as plt

plt.title('log_train_accuracy')
plt.plot(epoch , log_train_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('train_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_train_loss')
plt.plot(epoch , log_train_total_loss)
plt.xlabel('epoch')
plt.ylabel('train_loss')
plt.show()

# %% [markdown]
# ###**6. Plotting Test Accuracy & Loss**

# %%
import matplotlib.pyplot as plt

plt.title('log_test_accuracy')
plt.plot(epoch , log_test_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('test_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_test_loss')
plt.plot(epoch , log_test_total_loss)
plt.xlabel('epoch')
plt.ylabel('test_loss')
plt.show()

# %% [markdown]
# ###**7. Print Result**

# %%
print(log_train_total_accuracy)
print(log_train_total_loss) 
print(log_test_total_accuracy)
print(log_test_total_loss)
# Out:
# [92.19, 97.8, 98.38666666666667, 98.74, 98.95333333333333, 99.11166666666666, 99.17, 99.19833333333334, 99.25833333333334, 99.26833333333333, 99.275, 99.32666666666667, 99.39666666666666, 99.38666666666667, 99.38833333333334, 99.505, 99.32666666666667, 99.47333333333333, 99.47833333333334, 99.40333333333334]
# [225.69880310632288, 33.42051624157466, 23.909754170221277, 18.83605555142276, 15.825359959737398, 13.026846299588215, 11.568893547257176, 11.50420736981323, 10.444432824850082, 10.305908223206643, 10.0787859694683, 9.607659788918681, 8.832625389739405, 8.724685507535469, 9.07043096923735, 7.275066576490644, 9.390798871289007, 7.815654943260597, 7.717979227832984, 8.203844760952052]
# [97.82, 97.93, 98.87, 98.36, 99.1, 98.86, 98.92, 99.07, 98.75, 98.96, 98.99, 98.83, 98.99, 98.8, 99.09, 98.64, 98.93, 98.33, 98.72, 98.69]
# [0.0007274644062039442, 0.0006357198457466438, 0.0003572089217195753, 0.00050798283690674, 0.00029860753240936903, 0.00035752226608165073, 0.00031576446112958364, 0.0003228016897031921, 0.0003788476303321659, 0.0003144883289314748, 0.00033057121897436446, 0.0003228795153947431, 0.0003427324383355881, 0.0004302579949820938, 0.0002818873451447871, 0.0004232305781079049, 0.0003351247566941311, 0.0005688065864436794, 0.00041005924087658056, 0.0004107659961387981]

# %% [markdown]
# ###**8. Model Summary**

# %%
from torchsummary import summary

model = resnet18(1, 10)
summary(model.cuda(), (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 14, 14]           3,136
#        BatchNorm2d-2           [-1, 64, 14, 14]             128
#               ReLU-3           [-1, 64, 14, 14]               0
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#         Conv2dAuto-5             [-1, 64, 7, 7]          36,864
#        BatchNorm2d-6             [-1, 64, 7, 7]             128
#               ReLU-7             [-1, 64, 7, 7]               0
#         Conv2dAuto-8             [-1, 64, 7, 7]          36,864
#        BatchNorm2d-9             [-1, 64, 7, 7]             128
#  ResNetBasicBlock-10             [-1, 64, 7, 7]               0
#        Conv2dAuto-11             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-12             [-1, 64, 7, 7]             128
#              ReLU-13             [-1, 64, 7, 7]               0
#        Conv2dAuto-14             [-1, 64, 7, 7]          36,864
#       BatchNorm2d-15             [-1, 64, 7, 7]             128
#  ResNetBasicBlock-16             [-1, 64, 7, 7]               0
#       ResNetLayer-17             [-1, 64, 7, 7]               0
#            Conv2d-18            [-1, 128, 4, 4]           8,192
#       BatchNorm2d-19            [-1, 128, 4, 4]             256
#        Conv2dAuto-20            [-1, 128, 4, 4]          73,728
#       BatchNorm2d-21            [-1, 128, 4, 4]             256
#              ReLU-22            [-1, 128, 4, 4]               0
#        Conv2dAuto-23            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-24            [-1, 128, 4, 4]             256
#  ResNetBasicBlock-25            [-1, 128, 4, 4]               0
#        Conv2dAuto-26            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-27            [-1, 128, 4, 4]             256
#              ReLU-28            [-1, 128, 4, 4]               0
#        Conv2dAuto-29            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-30            [-1, 128, 4, 4]             256
#  ResNetBasicBlock-31            [-1, 128, 4, 4]               0
#       ResNetLayer-32            [-1, 128, 4, 4]               0
#            Conv2d-33            [-1, 256, 2, 2]          32,768
#       BatchNorm2d-34            [-1, 256, 2, 2]             512
#        Conv2dAuto-35            [-1, 256, 2, 2]         294,912
#       BatchNorm2d-36            [-1, 256, 2, 2]             512
#              ReLU-37            [-1, 256, 2, 2]               0
#        Conv2dAuto-38            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-39            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-40            [-1, 256, 2, 2]               0
#        Conv2dAuto-41            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-42            [-1, 256, 2, 2]             512
#              ReLU-43            [-1, 256, 2, 2]               0
#        Conv2dAuto-44            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-45            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-46            [-1, 256, 2, 2]               0
#       ResNetLayer-47            [-1, 256, 2, 2]               0
#            Conv2d-48            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-49            [-1, 512, 1, 1]           1,024
#        Conv2dAuto-50            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-51            [-1, 512, 1, 1]           1,024
#              ReLU-52            [-1, 512, 1, 1]               0
#        Conv2dAuto-53            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-54            [-1, 512, 1, 1]           1,024
#  ResNetBasicBlock-55            [-1, 512, 1, 1]               0
#        Conv2dAuto-56            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        Conv2dAuto-59            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-60            [-1, 512, 1, 1]           1,024
#  ResNetBasicBlock-61            [-1, 512, 1, 1]               0
#       ResNetLayer-62            [-1, 512, 1, 1]               0
#     ResNetEncoder-63            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-64            [-1, 512, 1, 1]               0
#            Linear-65                   [-1, 10]           5,130
#     ResnetDecoder-66                   [-1, 10]               0
# ================================================================
# Total params: 11,175,370
# Trainable params: 11,175,370
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.04
# Params size (MB): 42.63
# Estimated Total Size (MB): 43.67
# ----------------------------------------------------------------
