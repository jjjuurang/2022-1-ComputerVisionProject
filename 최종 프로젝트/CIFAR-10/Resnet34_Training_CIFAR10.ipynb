# %% [markdown]
# #**ResNet Training (CIFAR - 10)**

# %% [markdown]
# ###**1. Import Library & Define Resnet model**

# %%
import torch
import torch.nn as nn

from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os
import torchvision
import torchvision.transforms as transforms


class Conv2dAuto(nn.Conv2d):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.padding =  (self.kernel_size[0] // 2, self.kernel_size[1] // 2) # dynamic add padding based on the kernel_size
        

conv3x3 = partial(Conv2dAuto, kernel_size=3, bias=False)


class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.in_channels, self.out_channels =  in_channels, out_channels
        self.blocks = nn.Identity()
        self.shortcut = nn.Identity()   
    
    def forward(self, x):
        residual = x
        if self.should_apply_shortcut: residual = self.shortcut(x)
        x = self.blocks(x)
        x += residual
        return x
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.out_channels
    


class ResNetResidualBlock(ResidualBlock):
    def __init__(self, in_channels, out_channels, expansion=1, downsampling=1, conv=conv3x3, *args, **kwargs):
        super().__init__(in_channels, out_channels)
        self.expansion, self.downsampling, self.conv = expansion, downsampling, conv
        self.shortcut = nn.Sequential(OrderedDict(
        {
            'conv' : nn.Conv2d(self.in_channels, self.expanded_channels, kernel_size=1,
                      stride=self.downsampling, bias=False),
            'bn' : nn.BatchNorm2d(self.expanded_channels)
            
        })) if self.should_apply_shortcut else None
        
        
    @property
    def expanded_channels(self):
        return self.out_channels * self.expansion
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.expanded_channels

def conv_bn(in_channels, out_channels, conv, *args, **kwargs):
    return nn.Sequential(OrderedDict({'conv': conv(in_channels, out_channels, *args, **kwargs), 
                          'bn': nn.BatchNorm2d(out_channels) }))

class ResNetBasicBlock(ResNetResidualBlock):
    expansion = 1
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, *args, **kwargs)
        self.blocks = nn.Sequential(
            conv_bn(self.in_channels, self.out_channels, conv=self.conv, bias=False, stride=self.downsampling),
            activation(),
            conv_bn(self.out_channels, self.expanded_channels, conv=self.conv, bias=False),
        )
        
class ResNetBottleNeckBlock(ResNetResidualBlock):
    expansion = 4
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, expansion=4, *args, **kwargs)
        self.blocks = nn.Sequential(
           conv_bn(self.in_channels, self.out_channels, self.conv, kernel_size=1),
             activation(),
             conv_bn(self.out_channels, self.out_channels, self.conv, kernel_size=3, stride=self.downsampling),
             activation(),
             conv_bn(self.out_channels, self.expanded_channels, self.conv, kernel_size=1),
        )
        
class ResNetLayer(nn.Module):
    def __init__(self, in_channels, out_channels, block=ResNetBasicBlock, n=1, *args, **kwargs):
        super().__init__()
        # 'We perform downsampling directly by convolutional layers that have a stride of 2.'
        downsampling = 2 if in_channels != out_channels else 1
        
        self.blocks = nn.Sequential(
            block(in_channels , out_channels, *args, **kwargs, downsampling=downsampling),
            *[block(out_channels * block.expansion, 
                    out_channels, downsampling=1, *args, **kwargs) for _ in range(n - 1)]
        )

    def forward(self, x):
        x = self.blocks(x)
        return x
    
class ResNetEncoder(nn.Module):
    """
    ResNet encoder composed by increasing different layers with increasing features.
    """
    def __init__(self, in_channels=3, blocks_sizes=[64, 128, 256, 512], deepths=[2,2,2,2], 
                 activation=nn.ReLU, block=ResNetBasicBlock, *args,**kwargs):
        super().__init__()
        
        self.blocks_sizes = blocks_sizes
        
        self.gate = nn.Sequential(
            nn.Conv2d(in_channels, self.blocks_sizes[0], kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(self.blocks_sizes[0]),
            activation(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        
        self.in_out_block_sizes = list(zip(blocks_sizes, blocks_sizes[1:]))
        self.blocks = nn.ModuleList([ 
            ResNetLayer(blocks_sizes[0], blocks_sizes[0], n=deepths[0], activation=activation, 
                        block=block,  *args, **kwargs),
            *[ResNetLayer(in_channels * block.expansion, 
                          out_channels, n=n, activation=activation, 
                          block=block, *args, **kwargs) 
              for (in_channels, out_channels), n in zip(self.in_out_block_sizes, deepths[1:])]       
        ])
        
        
    def forward(self, x):
        x = self.gate(x)
        for block in self.blocks:
            x = block(x)
        return x
    

class ResnetDecoder(nn.Module):
    """
    This class represents the tail of ResNet. It performs a global pooling and maps the output to the
    correct class by using a fully connected layer.
    """
    def __init__(self, in_features, n_classes):
        super().__init__()
        self.avg = nn.AdaptiveAvgPool2d((1, 1))
        self.decoder = nn.Linear(in_features, n_classes)

    def forward(self, x):
        x = self.avg(x)
        x = x.view(x.size(0), -1)
        x = self.decoder(x)
        return x
    
class ResNet(nn.Module):
    
    def __init__(self, in_channels, n_classes, *args, **kwargs):
        super().__init__()
        self.encoder = ResNetEncoder(in_channels, *args, **kwargs)
        self.decoder = ResnetDecoder(self.encoder.blocks[-1].blocks[-1].expanded_channels, n_classes)
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
def resnet18(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[2, 2, 2, 2])

def resnet34(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[3, 4, 6, 3])

def resnet50(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 6, 3])

def resnet101(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 23, 3])

def resnet152(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 8, 36, 3])

# %% [markdown]
# ###**2. Download CIFAR-10**

# %%
#Download CIFAR10 DATASET

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ###**3. CUDA setting & Define Train,Test function**

# %%
#gpu setting & define Training function

device = 'cuda'

net = resnet34(3,10)           #resnet34 선언
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet34_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)
    total_accuracy = 100. * correct / total;

    return total_accuracy , train_loss


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)
    total_accuracy = 100. * correct / total;
    test_loss = loss / total

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

    return total_accuracy , test_loss

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# ###**4. Run Training & Save log**

# %%
# for epoch in range(0, 200):
log_train_total_accuracy =[]
log_train_total_loss = []
log_test_total_accuracy =[]
log_test_total_loss =[]


for epoch in range(0, 60):
    adjust_learning_rate(optimizer, epoch)
    train_total_accuracy, train_total_loss = train(epoch)
    test_total_accuracy, test_total_loss = test(epoch)
    log_train_total_accuracy.append(train_total_accuracy)
    log_train_total_loss.append(train_total_loss)
    log_test_total_accuracy.append(test_total_accuracy)
    log_test_total_loss.append(test_total_loss)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.09375
# Current benign train loss: 2.919400691986084
#
# Current batch: 100
# Current benign train accuracy: 0.1171875
# Current benign train loss: 2.397787094116211
#
# Current batch: 200
# Current benign train accuracy: 0.203125
# Current benign train loss: 2.1305301189422607
#
# Current batch: 300
# Current benign train accuracy: 0.2578125
# Current benign train loss: 1.9778615236282349
#
# Total benign train accuarcy: 18.9
# Total benign train loss: 1212.5383241176605
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 27.11
# Test average loss: 0.018895193815231325
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.21875
# Current benign train loss: 1.8974854946136475
#
# Current batch: 100
# Current benign train accuracy: 0.2890625
# Current benign train loss: 1.8752474784851074
#
# Current batch: 200
# Current benign train accuracy: 0.375
# Current benign train loss: 1.7918626070022583
#
# Current batch: 300
# Current benign train accuracy: 0.265625
# Current benign train loss: 1.8837833404541016
#
# Total benign train accuarcy: 32.504
# Total benign train loss: 695.1282670497894
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 36.9
# Test average loss: 0.016675763237476347
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.3125
# Current benign train loss: 1.8775749206542969
#
# Current batch: 100
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.5358450412750244
#
# Current batch: 200
# Current benign train accuracy: 0.40625
# Current benign train loss: 1.6577003002166748
#
# Current batch: 300
# Current benign train accuracy: 0.453125
# Current benign train loss: 1.5736522674560547
#
# Total benign train accuarcy: 38.5
# Total benign train loss: 644.419256567955
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 38.59
# Test average loss: 0.01663770020008087
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.6220896244049072
#
# Current batch: 100
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.465324878692627
#
# Current batch: 200
# Current benign train accuracy: 0.421875
# Current benign train loss: 1.480792760848999
#
# Current batch: 300
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.6095384359359741
#
# Total benign train accuarcy: 42.964
# Total benign train loss: 602.4449611902237
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 47.98
# Test average loss: 0.014220602977275848
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4375
# Current benign train loss: 1.619646430015564
#
# Current batch: 100
# Current benign train accuracy: 0.5
# Current benign train loss: 1.429404616355896
#
# Current batch: 200
# Current benign train accuracy: 0.421875
# Current benign train loss: 1.4185761213302612
#
# Current batch: 300
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.387513279914856
#
# Total benign train accuarcy: 47.256
# Total benign train loss: 562.2915885448456
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 46.95
# Test average loss: 0.014459035634994507
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5
# Current benign train loss: 1.416305661201477
#
# Current batch: 100
# Current benign train accuracy: 0.484375
# Current benign train loss: 1.3334952592849731
#
# Current batch: 200
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.475361943244934
#
# Current batch: 300
# Current benign train accuracy: 0.4453125
# Current benign train loss: 1.3932278156280518
#
# Total benign train accuarcy: 51.276
# Total benign train loss: 523.4415661096573
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 40.27
# Test average loss: 0.019023215568065643
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4765625
# Current benign train loss: 1.52715003490448
#
# Current batch: 100
# Current benign train accuracy: 0.46875
# Current benign train loss: 1.5236862897872925
#
# Current batch: 200
# Current benign train accuracy: 0.484375
# Current benign train loss: 1.2839874029159546
#
# Current batch: 300
# Current benign train accuracy: 0.5078125
# Current benign train loss: 1.4214447736740112
#
# Total benign train accuarcy: 54.178
# Total benign train loss: 494.79915618896484
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 51.97
# Test average loss: 0.013564098310470582
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0551162958145142
#
# Current batch: 100
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1404225826263428
#
# Current batch: 200
# Current benign train accuracy: 0.5
# Current benign train loss: 1.3821632862091064
#
# Current batch: 300
# Current benign train accuracy: 0.5078125
# Current benign train loss: 1.2857528924942017
#
# Total benign train accuarcy: 57.114
# Total benign train loss: 467.29433768987656
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 56.64
# Test average loss: 0.012333896392583848
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.2609087228775024
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.2020405530929565
#
# Current batch: 200
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.946894645690918
#
# Current batch: 300
# Current benign train accuracy: 0.6640625
# Current benign train loss: 1.0615606307983398
#
# Total benign train accuarcy: 59.45
# Total benign train loss: 444.50758308172226
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 54.34
# Test average loss: 0.012944436466693878
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0910075902938843
#
# Current batch: 100
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0152713060379028
#
# Current batch: 200
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.077613353729248
#
# Current batch: 300
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.1060274839401245
#
# Total benign train accuarcy: 61.45
# Total benign train loss: 423.86241257190704
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 63.52
# Test average loss: 0.010566405737400055
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.07962965965271
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0036137104034424
#
# Current batch: 200
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.1543573141098022
#
# Current batch: 300
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.1471015214920044
#
# Total benign train accuarcy: 63.146
# Total benign train loss: 405.5710338950157
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 61.19
# Test average loss: 0.010959746712446213
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1794819831848145
#
# Current batch: 100
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.9789192080497742
#
# Current batch: 200
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9758977890014648
#
# Current batch: 300
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.1996665000915527
#
# Total benign train accuarcy: 64.45
# Total benign train loss: 391.3622353672981
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 57.04
# Test average loss: 0.012092223465442658
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.051950454711914
#
# Current batch: 100
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9104905724525452
#
# Current batch: 200
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8611127734184265
#
# Current batch: 300
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0579726696014404
#
# Total benign train accuarcy: 66.052
# Total benign train loss: 375.35561192035675
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 49.84
# Test average loss: 0.015536928606033324
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0657938718795776
#
# Current batch: 100
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.0239381790161133
#
# Current batch: 200
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.875877320766449
#
# Current batch: 300
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8485094904899597
#
# Total benign train accuarcy: 66.968
# Total benign train loss: 363.3661440014839
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 65.08
# Test average loss: 0.009790593361854553
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8517052531242371
#
# Current batch: 100
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8824008703231812
#
# Current batch: 200
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.0883508920669556
#
# Current batch: 300
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.7973793745040894
#
# Total benign train accuarcy: 68.496
# Total benign train loss: 349.2614195942879
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 48.63
# Test average loss: 0.018001626241207123
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.8476133942604065
#
# Current batch: 100
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8461958169937134
#
# Current batch: 200
# Current benign train accuracy: 0.625
# Current benign train loss: 0.927061915397644
#
# Current batch: 300
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.0846532583236694
#
# Total benign train accuarcy: 69.154
# Total benign train loss: 342.42414647340775
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 68.16
# Test average loss: 0.009176175862550736
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.8432533740997314
#
# Current batch: 100
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9732787609100342
#
# Current batch: 200
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.7461389899253845
#
# Current batch: 300
# Current benign train accuracy: 0.6328125
# Current benign train loss: 0.9226881265640259
#
# Total benign train accuarcy: 70.388
# Total benign train loss: 332.01824098825455
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 57.49
# Test average loss: 0.014033872854709625
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.8075714111328125
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.668406069278717
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7884446978569031
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7348273396492004
#
# Total benign train accuarcy: 71.266
# Total benign train loss: 321.53937953710556
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 64.13
# Test average loss: 0.010512135243415833
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6488741040229797
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.8565080761909485
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.
#
# [ Train epoch: 58 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5814254879951477
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.6053093075752258
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5633789896965027
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4824582040309906
#
# Total benign train accuarcy: 81.576
# Total benign train loss: 208.69646456837654
#
# [ Test epoch: 58 ]
#
# Test accuarcy: 71.51
# Test average loss: 0.00881133423447609
# Model Saved!
#
# [ Train epoch: 59 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4309174120426178
#
# Current batch: 100
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.4112914502620697
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6091926693916321
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.4080314040184021
#
# Total benign train accuarcy: 81.598
# Total benign train loss: 209.20758974552155
#
# [ Test epoch: 59 ]
#
# Test accuarcy: 73.84
# Test average loss: 0.008234139829874039
# Model Saved!

# %%
file_name = "/content/checkpoint/resnet34_cifar10.pt"
device = 'cuda'

net = resnet34(3,10)
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])

file_name = 'resnet34_cifar10.pt'

for epoch in range(0, 40):
    adjust_learning_rate(optimizer, epoch)
    train_total_accuracy, train_total_loss = train(epoch)
    test_total_accuracy, test_total_loss = test(epoch)
    log_train_total_accuracy.append(train_total_accuracy)
    log_train_total_loss.append(train_total_loss)
    log_test_total_accuracy.append(test_total_accuracy)
    log_test_total_loss.append(test_total_loss)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5489342212677002
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5387042760848999
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4270043969154358
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.48665666580200195
#
# Total benign train accuarcy: 82.964
# Total benign train loss: 193.0108827650547
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 80.13
# Test average loss: 0.005743943303823471
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5909613370895386
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.38026249408721924
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5784406065940857
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5383470058441162
#
# Total benign train accuarcy: 82.882
# Total benign train loss: 194.28065994381905
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 80.11
# Test average loss: 0.0057804665595293046
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.47062650322914124
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4485483467578888
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3754311501979828
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3985850512981415
#
# Total benign train accuarcy: 82.912
# Total benign train loss: 195.42492926120758
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 80.17
# Test average loss: 0.0057875102490186695
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5295681953430176
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5140944719314575
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5898955464363098
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.49382269382476807
#
# Total benign train accuarcy: 82.942
# Total benign train loss: 194.38368892669678
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 80.06
# Test average loss: 0.005773358693718911
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5275015234947205
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5687146782875061
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.4971662759780884
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5182532668113708
#
# Total benign train accuarcy: 82.75
# Total benign train loss: 195.54301163554192
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 79.8
# Test average loss: 0.005834798654913902
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.39056190848350525
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4623051583766937
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.580385148525238
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.43952929973602295
#
# Total benign train accuarcy: 82.934
# Total benign train loss: 194.6631174981594
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 79.95
# Test average loss: 0.005752810445427895
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5375781655311584
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5190447568893433
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 0.43103471398353577
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3367272913455963
#
# Total benign train accuarcy: 82.728
# Total benign train loss: 195.77365589141846
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 80.13
# Test average loss: 0.005741556757688522
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6403548717498779
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5308449864387512
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4697813391685486
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.475165456533432
#
# Total benign train accuarcy: 82.906
# Total benign train loss: 195.081205368042
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 80.19
# Test average loss: 0.005770746874809265
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4990863800048828
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5544695258140564
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.44914209842681885
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4709087014198303
#
# Total benign train accuarcy: 82.938
# Total benign train loss: 195.00145721435547
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 80.29
# Test average loss: 0.0057342368215322495
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3488861322402954
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4676974415779114
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3853757679462433
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4800650477409363
#
# Total benign train accuarcy: 82.982
# Total benign train loss: 193.85131004452705
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 80.26
# Test average loss: 0.005804474714398384
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.35270068049430847
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3660937547683716
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5633782744407654
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.47617948055267334
#
# Total benign train accuarcy: 82.758
# Total benign train loss: 196.28805762529373
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 80.18
# Test average loss: 0.005764776250720024
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6579675674438477
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.44480231404304504
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.40971842408180237
#
# Current batch: 300
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.4096633493900299
#
# Total benign train accuarcy: 82.89
# Total benign train loss: 194.27478709816933
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 80.35
# Test average loss: 0.005760505554080009
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3195124864578247
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5927930474281311
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5180444121360779
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.38295209407806396
#
# Total benign train accuarcy: 82.928
# Total benign train loss: 194.87088522315025
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 80.19
# Test average loss: 0.0057288598895072936
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5291156768798828
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6205503344535828
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6304068565368652
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5592139959335327
#
# Total benign train accuarcy: 83.0
# Total benign train loss: 193.64336940646172
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 79.84
# Test average loss: 0.005829182615876198
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5776925683021545
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37872520089149475
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.4577041566371918
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.49447745084762573
#
# Total benign train accuarcy: 83.008
# Total benign train loss: 195.13252729177475
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 80.21
# Test average loss: 0.005737750461697578
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4869978129863739
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6168535351753235
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5421444177627563
#
# Current batch: 300
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.28750306367874146
#
# Total benign train accuarcy: 82.77
# Total benign train loss: 195.37177848815918
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 80.0
# Test average loss: 0.005814742365479469
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.636407732963562
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4144308567047119
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5194641351699829
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.604812741279602
#
# Total benign train accuarcy: 82.71
# Total benign train loss: 194.75855180621147
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 80.12
# Test average loss: 0.0057389440834522245
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5347515344619751
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3588419258594513
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.45181697607040405
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5034419894218445
#
# Total benign train accuarcy: 82.662
# Total benign train loss: 194.9352508187294
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 80.1
# Test average loss: 0.005766418594121933
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6070369482040405
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5390488505363464
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4015660583972931
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4661736786365509
#
# Total benign train accuarcy: 82.888
# Total benign train loss: 193.54775354266167
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 80.05
# Test average loss: 0.005744538357853889
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5371359586715698
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.48623785376548767
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.47685015201568604
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5830436944961548
#
# Total benign train accuarcy: 82.67
# Total benign train loss: 195.87414759397507
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 80.03
# Test average loss: 0.005798942127823829
# Model Saved!
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.345350444316864
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.40399932861328125
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4623270034790039
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4687165319919586
#
# Total benign train accuarcy: 82.798
# Total benign train loss: 194.89340963959694
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 80.22
# Test average loss: 0.005753790119290352
# Model Saved!
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5425826907157898
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.34160667657852173
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6300128698348999
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.317126989364624
#
# Total benign train accuarcy: 82.904
# Total benign train loss: 194.39281448721886
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 79.91
# Test average loss: 0.0058147316932678226
# Model Saved!
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6690226197242737
#
# Current batch: 100
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5627116560935974
#
# Current batch: 200
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6272503137588501
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5376724004745483
#
# Total benign train accuarcy: 82.716
# Total benign train loss: 195.40673246979713
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 79.95
# Test average loss: 0.005825841525197029
# Model Saved!
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.42882847785949707
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5091024041175842
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5188016891479492
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4893876314163208
#
# Total benign train accuarcy: 83.02
# Total benign train loss: 194.79383820295334
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 80.24
# Test average loss: 0.005770583468675613
# Model Saved!
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.37248513102531433
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.466196745634079
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4268712103366852
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5554236173629761
#
# Total benign train accuarcy: 82.958
# Total benign train loss: 194.14307707548141
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 80.07
# Test average loss: 0.005761914703249931
# Model Saved!
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.41382479667663574
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.35060548782348633
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5126441717147827
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5064657330513
#
# Total benign train accuarcy: 82.836
# Total benign train loss: 195.18500581383705
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 80.08
# Test average loss: 0.005749571245908737
# Model Saved!
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5192930102348328
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.5133429765701294
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4688476324081421
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.456082284450531
#
# Total benign train accuarcy: 82.806
# Total benign train loss: 195.491602987051
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 80.24
# Test average loss: 0.005758320382237434
# Model Saved!
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.39652273058891296
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.43543311953544617
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.5773051381111145
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6867071390151978
#
# Total benign train accuarcy: 82.716
# Total benign train loss: 194.40224587917328
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 80.15
# Test average loss: 0.0057857704252004625
# Model Saved!
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.40782400965690613
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5318087935447693
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5070497393608093
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4786219000816345
#
# Total benign train accuarcy: 83.002
# Total benign train loss: 193.0322269797325
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 80.02
# Test average loss: 0.005763966500759125
# Model Saved!
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.497553288936615
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.48129624128341675
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4082132577896118
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.48922276496887207
#
# Total benign train accuarcy: 82.838
# Total benign train loss: 194.42960858345032
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 80.27
# Test average loss: 0.005745309436321258
# Model Saved!
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.525050163269043
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3731249272823334
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5146416425704956
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.584621012210846
#
# Total benign train accuarcy: 82.934
# Total benign train loss: 194.22498443722725
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 79.86
# Test average loss: 0.005827454391121864
# Model Saved!
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.35904255509376526
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5541275143623352
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.45388495922088623
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.47614917159080505
#
# Total benign train accuarcy: 82.84
# Total benign train loss: 194.26355269551277
#
# [ Test epoch: 31 ]
#
# Test accuarcy: 80.04
# Test average loss: 0.005767956936359405
# Model Saved!
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5126855373382568
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6142230033874512
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5876327753067017
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6787054538726807
#
# Total benign train accuarcy: 82.762
# Total benign train loss: 195.18522971868515
#
# [ Test epoch: 32 ]
#
# Test accuarcy: 80.23
# Test average loss: 0.005757530850172042
# Model Saved!
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5457305908203125
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3918548822402954
#
# Current batch: 200
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5645402669906616
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.40973255038261414
#
# Total benign train accuarcy: 82.88
# Total benign train loss: 195.03697609901428
#
# [ Test epoch: 33 ]
#
# Test accuarcy: 80.09
# Test average loss: 0.005790105736255646
# Model Saved!
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4173015058040619
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.43428218364715576
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4120107889175415
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6281334757804871
#
# Total benign train accuarcy: 82.938
# Total benign train loss: 194.18967136740685
#
# [ Test epoch: 34 ]
#
# Test accuarcy: 80.13
# Test average loss: 0.005739171954989433
# Model Saved!
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3810449540615082
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5578315258026123
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5915111303329468
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5393890142440796
#
# Total benign train accuarcy: 82.962
# Total benign train loss: 193.50715216994286
#
# [ Test epoch: 35 ]
#
# Test accuarcy: 80.01
# Test average loss: 0.005806612089276314
# Model Saved!
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6397171020507812
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4778345823287964
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.44443535804748535
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4109700322151184
#
# Total benign train accuarcy: 82.884
# Total benign train loss: 193.53653126955032
#
# [ Test epoch: 36 ]
#
# Test accuarcy: 80.14
# Test average loss: 0.005756188827753067
# Model Saved!
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5014238357543945
#
# Current batch: 100
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.5594423413276672
#
# Current batch: 200
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.6538693308830261
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.37049463391304016
#
# Total benign train accuarcy: 82.872
# Total benign train loss: 194.77088460326195
#
# [ Test epoch: 37 ]
#
# Test accuarcy: 80.13
# Test average loss: 0.005794323801994324
# Model Saved!
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.49139824509620667
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.472140371799469
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.492633581161499
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5506646037101746
#
# Total benign train accuarcy: 82.976
# Total benign train loss: 193.96051797270775
#
# [ Test epoch: 38 ]
#
# Test accuarcy: 80.15
# Test average loss: 0.00574769968688488
# Model Saved!
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.42717862129211426
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5492296814918518
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5061244368553162
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6654427647590637
#
# Total benign train accuarcy: 82.722
# Total benign train loss: 194.39809253811836
#
# [ Test epoch: 39 ]
#
# Test accuarcy: 80.28
# Test average loss: 0.005807333070039749
# Model Saved!

# %% [markdown]
# ###**5. Plotting Train Accuracy & Loss**

# %%
epoch =[]

for i , loss in enumerate(log_test_total_loss):
  epoch.append(i+1)

import matplotlib.pyplot as plt

plt.title('log_train_accuracy')
plt.plot(epoch , log_train_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('train_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_train_loss')
plt.plot(epoch , log_train_total_loss)
plt.xlabel('epoch')
plt.ylabel('train_loss')
plt.show()

# %% [markdown]
# ###**6. Plotting Test Accuracy & Loss**

# %%
import matplotlib.pyplot as plt

plt.title('log_test_accuracy')
plt.plot(epoch , log_test_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('test_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_test_loss')
plt.plot(epoch , log_test_total_loss)
plt.xlabel('epoch')
plt.ylabel('test_loss')
plt.show()

# %% [markdown]
# ###**7. Print Result**

# %%
print(log_train_total_accuracy)
print(log_train_total_loss) 
print(log_test_total_accuracy)
print(log_test_total_loss)
# Out:
# [18.9, 32.504, 38.5, 42.964, 47.256, 51.276, 54.178, 57.114, 59.45, 61.45, 63.146, 64.45, 66.052, 66.968, 68.496, 69.154, 70.388, 71.266, 71.94, 72.916, 73.368, 73.996, 74.214, 74.692, 75.452, 75.614, 76.166, 76.36, 77.034, 77.124, 77.326, 77.756, 78.13, 77.992, 78.59, 78.642, 79.15, 79.046, 79.234, 79.276, 79.38, 79.792, 79.808, 79.806, 80.112, 80.218, 80.378, 80.828, 80.818, 80.776, 80.858, 80.904, 81.042, 81.09, 81.046, 81.5, 81.498, 81.608, 81.576, 81.598, 82.964, 82.
[-1, 128, 4, 4]         147,456
#       BatchNorm2d-36            [-1, 128, 4, 4]             256
#  ResNetBasicBlock-37            [-1, 128, 4, 4]               0
#        Conv2dAuto-38            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-39            [-1, 128, 4, 4]             256
#              ReLU-40            [-1, 128, 4, 4]               0
#        Conv2dAuto-41            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-42            [-1, 128, 4, 4]             256
#  ResNetBasicBlock-43            [-1, 128, 4, 4]               0
#        Conv2dAuto-44            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-45            [-1, 128, 4, 4]             256
#              ReLU-46            [-1, 128, 4, 4]               0
#        Conv2dAuto-47            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-48            [-1, 128, 4, 4]             256
#  ResNetBasicBlock-49            [-1, 128, 4, 4]               0
#       ResNetLayer-50            [-1, 128, 4, 4]               0
#            Conv2d-51            [-1, 256, 2, 2]          32,768
#       BatchNorm2d-52            [-1, 256, 2, 2]             512
#        Conv2dAuto-53            [-1, 256, 2, 2]         294,912
#       BatchNorm2d-54            [-1, 256, 2, 2]             512
#              ReLU-55            [-1, 256, 2, 2]               0
#        Conv2dAuto-56            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-57            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-58            [-1, 256, 2, 2]               0
#        Conv2dAuto-59            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-60            [-1, 256, 2, 2]             512
#              ReLU-61            [-1, 256, 2, 2]               0
#        Conv2dAuto-62            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-63            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-64            [-1, 256, 2, 2]               0
#        Conv2dAuto-65            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-66            [-1, 256, 2, 2]             512
#              ReLU-67            [-1, 256, 2, 2]               0
#        Conv2dAuto-68            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-69            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-70            [-1, 256, 2, 2]               0
#        Conv2dAuto-71            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-72            [-1, 256, 2, 2]             512
#              ReLU-73            [-1, 256, 2, 2]               0
#        Conv2dAuto-74            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-75            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-76            [-1, 256, 2, 2]               0
#        Conv2dAuto-77            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-78            [-1, 256, 2, 2]             512
#              ReLU-79            [-1, 256, 2, 2]               0
#        Conv2dAuto-80            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-81            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-82            [-1, 256, 2, 2]               0
#        Conv2dAuto-83            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-84            [-1, 256, 2, 2]             512
#              ReLU-85            [-1, 256, 2, 2]               0
#        Conv2dAuto-86            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-87            [-1, 256, 2, 2]             512
#  ResNetBasicBlock-88            [-1, 256, 2, 2]               0
#       ResNetLayer-89            [-1, 256, 2, 2]               0
#            Conv2d-90            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-91            [-1, 512, 1, 1]           1,024
#        Conv2dAuto-92            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-93            [-1, 512, 1, 1]           1,024
#              ReLU-94            [-1, 512, 1, 1]               0
#        Conv2dAuto-95            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-96            [-1, 512, 1, 1]           1,024
#  ResNetBasicBlock-97            [-1, 512, 1, 1]               0
#        Conv2dAuto-98            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-99            [-1, 512, 1, 1]           1,024
#             ReLU-100            [-1, 512, 1, 1]               0
#       Conv2dAuto-101            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-102            [-1, 512, 1, 1]           1,024
# ResNetBasicBlock-103            [-1, 512, 1, 1]               0
#       Conv2dAuto-104            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-105            [-1, 512, 1, 1]           1,024
#             ReLU-106            [-1, 512, 1, 1]               0
#       Conv2dAuto-107            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-108            [-1, 512, 1, 1]           1,024
# ResNetBasicBlock-109            [-1, 512, 1, 1]               0
#      ResNetLayer-110            [-1, 512, 1, 1]               0
#    ResNetEncoder-111            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-112            [-1, 512, 1, 1]               0
#           Linear-113                   [-1, 10]           5,130
#    ResnetDecoder-114                   [-1, 10]               0
# ================================================================
# Total params: 21,289,802
# Trainable params: 21,289,802
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.82
# Params size (MB): 81.21
# Estimated Total Size (MB): 83.04
# ----------------------------------------------------------------
