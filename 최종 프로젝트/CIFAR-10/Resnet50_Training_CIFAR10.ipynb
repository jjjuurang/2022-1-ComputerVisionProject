# %% [markdown]
# #**ResNet Training (CIFAR - 10)**

# %% [markdown]
# ###**1. Import Library & Define Resnet model**

# %%
import torch
import torch.nn as nn

from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os
import torchvision
import torchvision.transforms as transforms


class Conv2dAuto(nn.Conv2d):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.padding =  (self.kernel_size[0] // 2, self.kernel_size[1] // 2) # dynamic add padding based on the kernel_size
        

conv3x3 = partial(Conv2dAuto, kernel_size=3, bias=False)


class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.in_channels, self.out_channels =  in_channels, out_channels
        self.blocks = nn.Identity()
        self.shortcut = nn.Identity()   
    
    def forward(self, x):
        residual = x
        if self.should_apply_shortcut: residual = self.shortcut(x)
        x = self.blocks(x)
        x += residual
        return x
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.out_channels
    


class ResNetResidualBlock(ResidualBlock):
    def __init__(self, in_channels, out_channels, expansion=1, downsampling=1, conv=conv3x3, *args, **kwargs):
        super().__init__(in_channels, out_channels)
        self.expansion, self.downsampling, self.conv = expansion, downsampling, conv
        self.shortcut = nn.Sequential(OrderedDict(
        {
            'conv' : nn.Conv2d(self.in_channels, self.expanded_channels, kernel_size=1,
                      stride=self.downsampling, bias=False),
            'bn' : nn.BatchNorm2d(self.expanded_channels)
            
        })) if self.should_apply_shortcut else None
        
        
    @property
    def expanded_channels(self):
        return self.out_channels * self.expansion
    
    @property
    def should_apply_shortcut(self):
        return self.in_channels != self.expanded_channels

def conv_bn(in_channels, out_channels, conv, *args, **kwargs):
    return nn.Sequential(OrderedDict({'conv': conv(in_channels, out_channels, *args, **kwargs), 
                          'bn': nn.BatchNorm2d(out_channels) }))

class ResNetBasicBlock(ResNetResidualBlock):
    expansion = 1
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, *args, **kwargs)
        self.blocks = nn.Sequential(
            conv_bn(self.in_channels, self.out_channels, conv=self.conv, bias=False, stride=self.downsampling),
            activation(),
            conv_bn(self.out_channels, self.expanded_channels, conv=self.conv, bias=False),
        )
        
class ResNetBottleNeckBlock(ResNetResidualBlock):
    expansion = 4
    def __init__(self, in_channels, out_channels, activation=nn.ReLU, *args, **kwargs):
        super().__init__(in_channels, out_channels, expansion=4, *args, **kwargs)
        self.blocks = nn.Sequential(
           conv_bn(self.in_channels, self.out_channels, self.conv, kernel_size=1),
             activation(),
             conv_bn(self.out_channels, self.out_channels, self.conv, kernel_size=3, stride=self.downsampling),
             activation(),
             conv_bn(self.out_channels, self.expanded_channels, self.conv, kernel_size=1),
        )
        
class ResNetLayer(nn.Module):
    def __init__(self, in_channels, out_channels, block=ResNetBasicBlock, n=1, *args, **kwargs):
        super().__init__()
        # 'We perform downsampling directly by convolutional layers that have a stride of 2.'
        downsampling = 2 if in_channels != out_channels else 1
        
        self.blocks = nn.Sequential(
            block(in_channels , out_channels, *args, **kwargs, downsampling=downsampling),
            *[block(out_channels * block.expansion, 
                    out_channels, downsampling=1, *args, **kwargs) for _ in range(n - 1)]
        )

    def forward(self, x):
        x = self.blocks(x)
        return x
    
class ResNetEncoder(nn.Module):
    """
    ResNet encoder composed by increasing different layers with increasing features.
    """
    def __init__(self, in_channels=3, blocks_sizes=[64, 128, 256, 512], deepths=[2,2,2,2], 
                 activation=nn.ReLU, block=ResNetBasicBlock, *args,**kwargs):
        super().__init__()
        
        self.blocks_sizes = blocks_sizes
        
        self.gate = nn.Sequential(
            nn.Conv2d(in_channels, self.blocks_sizes[0], kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(self.blocks_sizes[0]),
            activation(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        
        self.in_out_block_sizes = list(zip(blocks_sizes, blocks_sizes[1:]))
        self.blocks = nn.ModuleList([ 
            ResNetLayer(blocks_sizes[0], blocks_sizes[0], n=deepths[0], activation=activation, 
                        block=block,  *args, **kwargs),
            *[ResNetLayer(in_channels * block.expansion, 
                          out_channels, n=n, activation=activation, 
                          block=block, *args, **kwargs) 
              for (in_channels, out_channels), n in zip(self.in_out_block_sizes, deepths[1:])]       
        ])
        
        
    def forward(self, x):
        x = self.gate(x)
        for block in self.blocks:
            x = block(x)
        return x
    

class ResnetDecoder(nn.Module):
    """
    This class represents the tail of ResNet. It performs a global pooling and maps the output to the
    correct class by using a fully connected layer.
    """
    def __init__(self, in_features, n_classes):
        super().__init__()
        self.avg = nn.AdaptiveAvgPool2d((1, 1))
        self.decoder = nn.Linear(in_features, n_classes)

    def forward(self, x):
        x = self.avg(x)
        x = x.view(x.size(0), -1)
        x = self.decoder(x)
        return x
    
class ResNet(nn.Module):
    
    def __init__(self, in_channels, n_classes, *args, **kwargs):
        super().__init__()
        self.encoder = ResNetEncoder(in_channels, *args, **kwargs)
        self.decoder = ResnetDecoder(self.encoder.blocks[-1].blocks[-1].expanded_channels, n_classes)
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
def resnet18(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[2, 2, 2, 2])

def resnet34(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBasicBlock, deepths=[3, 4, 6, 3])

def resnet50(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 6, 3])

def resnet101(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 4, 23, 3])

def resnet152(in_channels, n_classes):
    return ResNet(in_channels, n_classes, block=ResNetBottleNeckBlock, deepths=[3, 8, 36, 3])

# %% [markdown]
# ###**2. Download CIFAR-10**

# %%
#Download CIFAR10 DATASET

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ###**3. CUDA setting & Define Train,Test function**

# %%
#gpu setting & define Training function

device = 'cuda'

net = resnet50(3,10)           #resnet50 선언
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet50_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)
    total_accuracy = 100. * correct / total;

    return total_accuracy , train_loss


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)
    total_accuracy = 100. * correct / total;
    test_loss = loss / total

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

    return total_accuracy , test_loss

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# ###**4. Run Training & Save log**

# %%
# for epoch in range(0, 200):
log_train_total_accuracy =[]
log_train_total_loss = []
log_test_total_accuracy =[]
log_test_total_loss =[]


for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train_total_accuracy, train_total_loss = train(epoch)
    test_total_accuracy, test_total_loss = test(epoch)
    log_train_total_accuracy.append(train_total_accuracy)
    log_train_total_loss.append(train_total_loss)
    log_test_total_accuracy.append(test_total_accuracy)
    log_test_total_loss.append(test_total_loss)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.09375
# Current benign train loss: 3.0253231525421143
#
# Current batch: 100
# Current benign train accuracy: 0.125
# Current benign train loss: 4.79644775390625
#
# Current batch: 200
# Current benign train accuracy: 0.0859375
# Current benign train loss: 2.3693463802337646
#
# Current batch: 300
# Current benign train accuracy: 0.1015625
# Current benign train loss: 2.2695343494415283
#
# Total benign train accuarcy: 12.946
# Total benign train loss: 3814.7059783935547
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 16.09
# Test average loss: 0.023286088109016417
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.15625
# Current benign train loss: 2.2349958419799805
#
# Current batch: 100
# Current benign train accuracy: 0.1171875
# Current benign train loss: 2.188258409500122
#
# Current batch: 200
# Current benign train accuracy: 0.21875
# Current benign train loss: 2.137704849243164
#
# Current batch: 300
# Current benign train accuracy: 0.2109375
# Current benign train loss: 2.202929735183716
#
# Total benign train accuarcy: 18.738
# Total benign train loss: 846.4653816223145
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 22.04
# Test average loss: 0.022428098893165587
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.171875
# Current benign train loss: 2.1676838397979736
#
# Current batch: 100
# Current benign train accuracy: 0.2421875
# Current benign train loss: 2.0270891189575195
#
# Current batch: 200
# Current benign train accuracy: 0.25
# Current benign train loss: 1.9326446056365967
#
# Current batch: 300
# Current benign train accuracy: 0.28125
# Current benign train loss: 1.9486758708953857
#
# Total benign train accuarcy: 24.546
# Total benign train loss: 783.8247088193893
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 30.19
# Test average loss: 0.01993591248989105
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.867173433303833
#
# Current batch: 100
# Current benign train accuracy: 0.265625
# Current benign train loss: 1.8693517446517944
#
# Current batch: 200
# Current benign train accuracy: 0.3125
# Current benign train loss: 1.9186761379241943
#
# Current batch: 300
# Current benign train accuracy: 0.3203125
# Current benign train loss: 1.8257750272750854
#
# Total benign train accuarcy: 30.09
# Total benign train loss: 728.7373812198639
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 35.63
# Test average loss: 0.017723437762260437
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.375
# Current benign train loss: 1.719420075416565
#
# Current batch: 100
# Current benign train accuracy: 0.2578125
# Current benign train loss: 1.9223366975784302
#
# Current batch: 200
# Current benign train accuracy: 0.3671875
# Current benign train loss: 1.804425597190857
#
# Current batch: 300
# Current benign train accuracy: 0.3671875
# Current benign train loss: 1.7830076217651367
#
# Total benign train accuarcy: 33.566
# Total benign train loss: 698.0003483295441
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 38.16
# Test average loss: 0.01717396194934845
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.3671875
# Current benign train loss: 1.6583504676818848
#
# Current batch: 100
# Current benign train accuracy: 0.3203125
# Current benign train loss: 1.8242267370224
#
# Current batch: 200
# Current benign train accuracy: 0.34375
# Current benign train loss: 1.778744101524353
#
# Current batch: 300
# Current benign train accuracy: 0.3203125
# Current benign train loss: 1.6796960830688477
#
# Total benign train accuarcy: 36.452
# Total benign train loss: 671.0692794322968
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 38.72
# Test average loss: 0.016645873069763183
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.34375
# Current benign train loss: 1.7290040254592896
#
# Current batch: 100
# Current benign train accuracy: 0.375
# Current benign train loss: 1.5468459129333496
#
# Current batch: 200
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.8761675357818604
#
# Current batch: 300
# Current benign train accuracy: 0.359375
# Current benign train loss: 1.6256541013717651
#
# Total benign train accuarcy: 38.622
# Total benign train loss: 649.7142281532288
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 36.71
# Test average loss: 0.017366767477989195
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.3515625
# Current benign train loss: 1.7154605388641357
#
# Current batch: 100
# Current benign train accuracy: 0.390625
# Current benign train loss: 1.6182516813278198
#
# Current batch: 200
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.627824068069458
#
# Current batch: 300
# Current benign train accuracy: 0.4453125
# Current benign train loss: 1.3733246326446533
#
# Total benign train accuarcy: 40.794
# Total benign train loss: 626.3825128078461
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 45.8
# Test average loss: 0.014831097722053528
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.5521928071975708
#
# Current batch: 100
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.559089183807373
#
# Current batch: 200
# Current benign train accuracy: 0.390625
# Current benign train loss: 1.598626732826233
#
# Current batch: 300
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.4738705158233643
#
# Total benign train accuarcy: 43.51
# Total benign train loss: 602.6293115615845
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 48.36
# Test average loss: 0.014236301565170289
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.4110008478164673
#
# Current batch: 100
# Current benign train accuracy: 0.4765625
# Current benign train loss: 1.455783486366272
#
# Current batch: 200
# Current benign train accuracy: 0.4453125
# Current benign train loss: 1.4790400266647339
#
# Current batch: 300
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.3596857786178589
#
# Total benign train accuarcy: 45.744
# Total benign train loss: 580.0362293720245
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 36.95
# Test average loss: 0.019006655287742615
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4921875
# Current benign train loss: 1.3936275243759155
#
# Current batch: 100
# Current benign train accuracy: 0.4375
# Current benign train loss: 1.5041123628616333
#
# Current batch: 200
# Current benign train accuracy: 0.4921875
# Current benign train loss: 1.351114273071289
#
# Current batch: 300
# Current benign train accuracy: 0.5
# Current benign train loss: 1.3831818103790283
#
# Total benign train accuarcy: 48.306
# Total benign train loss: 557.822108745575
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 51.01
# Test average loss: 0.013990921318531037
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5
# Current benign train loss: 1.4164479970932007
#
# Current batch: 100
# Current benign train accuracy: 0.5546875
# Current benign train loss: 1.3766145706176758
#
# Current batch: 200
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.3307465314865112
#
# Current batch: 300
# Current benign train accuracy: 0.546875
# Current benign train loss: 1.2165268659591675
#
# Total benign train accuarcy: 50.288
# Total benign train loss: 537.2182970046997
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 48.56
# Test average loss: 0.01488193941116333
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.2255297899246216
#
# Current batch: 100
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.2963711023330688
#
# Current batch: 200
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.307065725326538
#
# Current batch: 300
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.2579114437103271
#
# Total benign train accuarcy: 52.324
# Total benign train loss: 519.5971615314484
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 44.38
# Test average loss: 0.017211783349514006
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.2882136106491089
#
# Current batch: 100
# Current benign train accuracy: 0.5078125
# Current benign train loss: 1.3385319709777832
#
# Current batch: 200
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.309712290763855
#
# Current batch: 300
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.2064077854156494
#
# Total benign train accuarcy: 54.232
# Total benign train loss: 500.2498313188553
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 56.54
# Test average loss: 0.012890874218940735
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.546875
# Current benign train loss: 1.246597409248352
#
# Current batch: 100
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.193817377090454
#
# Current batch: 200
# Current benign train accuracy: 0.5
# Current benign train loss: 1.305753469467163
#
# Current batch: 300
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.2575080394744873
#
# Total benign train accuarcy: 55.386
# Total benign train loss: 488.36277812719345
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 53.72
# Test average loss: 0.013439315557479858
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.3322250843048096
#
# Current batch: 100
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.0525847673416138
#
# Current batch: 200
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1703656911849976
#
# Current batch: 300
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.1722608804702759
#
# Total benign train accuarcy: 57.164
# Total benign train loss: 472.786985874176
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 57.4
# Test average loss: 0.013744842028617858
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.625
# Current benign train loss: 1.1173810958862305
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.1296405792236328
#
# Current batch: 200
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.0232517719268799
#
# Current batch: 300
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.2502315044403076
#
# Total benign train accuarcy: 58.142
# Total benign train loss: 460.52961736917496
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 51.38
# Test average loss: 0.018314416766166686
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.1765789985656738
#
# Current batch: 100
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0247325897216797
#
# Current batch: 200
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.1876579523086548
#
# Current batch: 300
# Current benign train accuracy: 0.6640625
# Current benign train loss: 1.0421818494796753
#
# Total benign train accuarcy: 59.506
# Total benign train loss: 448.50873416662216
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 55.9
# Test average loss: 0.01260468630194664
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0429855585098267
#
# Current batch: 100
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.1200263500213623
#
# Current batch: 200
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9247190356254578
#
# Current batch: 300
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0887482166290283
#
# Total benign train accuarcy: 60.386
# Total benign train loss: 435.07959485054016
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 62.88
# Test average loss: 0.010713765335083008
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8573148250579834
#
# Current batch: 100
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.005953073501587
#
# Current batch: 200
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.9300336837768555
#
# Current batch: 300
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9882055521011353
#
# Total benign train accuarcy: 61.44
# Total benign train loss: 422.94924008846283
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 60.94
# Test average loss: 0.011045042842626572
# Model Saved!

# %%
file_name = "/content/checkpoint/resnet50_cifar10.pt"
device = 'cuda'

net = resnet50(3,10)
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

checkpoint = torch.load(file_name)
net.load_state_dict(checkpoint['net'])
# Out:
# <All keys matched successfully>

# %%
file_name = 'resnet50_cifar10.pt'

for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train_total_accuracy, train_total_loss = train(epoch)
    test_total_accuracy, test_total_loss = test(epoch)
    log_train_total_accuracy.append(train_total_accuracy)
    log_train_total_loss.append(train_total_loss)
    log_test_total_accuracy.append(test_total_accuracy)
    log_test_total_loss.append(test_total_loss)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.640625
# Current benign train loss: 1.0609132051467896
#
# Current batch: 100
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9903774261474609
#
# Current batch: 200
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0280274152755737
#
# Current batch: 300
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.1077640056610107
#
# Total benign train accuarcy: 61.832
# Total benign train loss: 417.2637212276459
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 63.37
# Test average loss: 0.010410763502120971
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.013287901878357
#
# Current batch: 100
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.9675886034965515
#
# Current batch: 200
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.0922036170959473
#
# Current batch: 300
# Current benign train accuracy: 0.671875
# Current benign train loss: 1.0525736808776855
#
# Total benign train accuarcy: 61.608
# Total benign train loss: 417.7470096349716
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 62.91
# Test average loss: 0.010481313949823379
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.1480919122695923
#
# Current batch: 100
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0595163106918335
#
# Current batch: 200
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0898783206939697
#
# Current batch: 300
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.0575083494186401
#
# Total benign train accuarcy: 61.8
# Total benign train loss: 416.6445745229721
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 63.31
# Test average loss: 0.010385043644905091
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.1039743423461914
#
# Current batch: 100
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.0857162475585938
#
# Current batch: 200
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0128276348114014
#
# Current batch: 300
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.1422290802001953
#
# Total benign train accuarcy: 61.694
# Total benign train loss: 418.29513245821
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 63.19
# Test average loss: 0.010409798228740693
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9442022442817688
#
# Current batch: 100
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.0523874759674072
#
# Current batch: 200
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.141331434249878
#
# Current batch: 300
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.0806984901428223
#
# Total benign train accuarcy: 61.672
# Total benign train loss: 416.58850115537643
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 63.33
# Test average loss: 0.010348234730958939
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1297357082366943
#
# Current batch: 100
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.8828005194664001
#
# Current batch: 200
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9455506801605225
#
# Current batch: 300
# Current benign train accuracy: 0.59375
# Current benign train loss: 0.9964307546615601
#
# Total benign train accuarcy: 61.774
# Total benign train loss: 417.2478803396225
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 63.39
# Test average loss: 0.010346965545415879
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.625
# Current benign train loss: 1.1982849836349487
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0600770711898804
#
# Current batch: 200
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0576503276824951
#
# Current batch: 300
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.2217034101486206
#
# Total benign train accuarcy: 61.884
# Total benign train loss: 416.7397190928459
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 63.04
# Test average loss: 0.01046446340084076
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1138631105422974
#
# Current batch: 100
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0682957172393799
#
# Current batch: 200
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.12410569190979
#
# Current batch: 300
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.122840404510498
#
# Total benign train accuarcy: 61.958
# Total benign train loss: 416.7211244106293
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 62.76
# Test average loss: 0.010497760653495789
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1021665334701538
#
# Current batch: 100
# Current benign train accuracy: 0.6640625
# Current benign train loss: 1.081587553024292
#
# Current batch: 200
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0086361169815063
#
# Current batch: 300
# Current benign train accuracy: 0.6640625
# Current benign train loss: 1.017778992652893
#
# Total benign train accuarcy: 61.74
# Total benign train loss: 418.0885930657387
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 62.78
# Test average loss: 0.010534759175777435
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.2165875434875488
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0328447818756104
#
# Current batch: 200
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1758233308792114
#
# Current batch: 300
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.0524570941925049
#
# Total benign train accuarcy: 61.89
# Total benign train loss: 416.8575894832611
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 63.33
# Test average loss: 0.01037506199479103
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0060919523239136
#
# Current batch: 100
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.9164040088653564
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 0.9124651551246643
#
# Current batch: 300
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0877048969268799
#
# Total benign train accuarcy: 61.598
# Total benign train loss: 417.81531089544296
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 63.22
# Test average loss: 0.010414671576023101
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.9851173758506775
#
# Current batch: 100
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.9904556274414062
#
# Current batch: 200
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.167597770690918
#
# Current batch: 300
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.141371726989746
#
# Total benign train accuarcy: 61.666
# Total benign train loss: 419.9363491535187
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 63.3
# Test average loss: 0.010398770302534104
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.245543122291565
#
# Current batch: 100
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8380928635597229
#
# Current batch: 200
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.133514404296875
#
# Current batch: 300
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.117255687713623
#
# Total benign train accuarcy: 61.684
# Total benign train loss: 417.6301454901695
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 63.21
# Test average loss: 0.01040395582318306
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.1050418615341187
#
# Current batch: 100
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.1015515327453613
#
# Current batch: 200
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.3345402479171753
#
# Current batch: 300
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1891148090362549
#
# Total benign train accuarcy: 61.848
# Total benign train loss: 417.3701478242874
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 63.3
# Test average loss: 0.010361654996871947
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.0661547183990479
#
# Current batch: 100
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.089285135269165
#
# Current batch: 200
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.915758490562439
#
# Current batch: 300
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.0390143394470215
#
# Total benign train accuarcy: 61.76
# Total benign train loss: 415.7026116847992
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 63.12
# Test average loss: 0.010431204742193221
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6796875
# Current benign train loss: 1.0098979473114014
#
# Current batch: 100
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.9594556093215942
#
# Current batch: 200
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.0696403980255127
#
# Current batch: 300
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.155967354774475
#
# Total benign train accuarcy: 61.704
# Total benign train loss: 418.9279046654701
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 62.91
# Test average loss: 0.010499510860443114
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0607339143753052
#
# Current batch: 100
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.8795902729034424
#
# Current batch: 200
# Current benign train accuracy: 0.6640625
# Current benign train loss: 1.0569474697113037
#
# Current batch: 300
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.1594040393829346
#
# Total benign train accuarcy: 61.902
# Total benign train loss: 415.8134568333626
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 63.38
# Test average loss: 0.010355972719192506
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.115769386291504
#
# Current batch: 100
# Current benign train accuracy: 0.625
# Current benign train loss: 1.04874849319458
#
# Current batch: 200
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.179092526435852
#
# Current batch: 300
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1961679458618164
#
# Total benign train accuarcy: 61.82
# Total benign train loss: 416.0751254558563
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 63.24
# Test average loss: 0.010366973978281022
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.0853532552719116
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 0.9560302495956421
#
# Current batch: 200
# Current benign train accuracy: 0.6015625
# Current benign train loss: 0.9834085702896118
#
# Current batch: 300
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.183426856994629
#
# Total benign train accuarcy: 61.806
# Total benign train loss: 416.8609573841095
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 63.41
# Test average loss: 0.010383375984430314
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8992934226989746
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0701143741607666
#
# Current batch: 200
# Current benign train accuracy: 0.6484375
# Current benign train loss: 0.9785827994346619
#
# Current batch: 300
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.0834197998046875
#
# Total benign train accuarcy: 61.974
# Total benign train loss: 416.7900730371475
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 63.21
# Test average loss: 0.010440591621398926
# Model Saved!

# %% [markdown]
# ###**5. Plotting Train Accuracy & Loss**

# %%
epoch =[]

for i , loss in enumerate(log_test_total_loss):
  epoch.append(i+1)

import matplotlib.pyplot as plt

plt.title('log_train_accuracy')
plt.plot(epoch , log_train_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('train_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_train_loss')
plt.plot(epoch , log_train_total_loss)
plt.xlabel('epoch')
plt.ylabel('train_loss')
plt.show()

# %% [markdown]
# ###**6. Plotting Test Accuracy & Loss**

# %%
import matplotlib.pyplot as plt

plt.title('log_test_accuracy')
plt.plot(epoch , log_test_total_accuracy)
plt.xlabel('epoch')
plt.ylabel('test_accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('log_test_loss')
plt.plot(epoch , log_test_total_loss)
plt.xlabel('epoch')
plt.ylabel('test_loss')
plt.show()

# %% [markdown]
# ###**7. Print Result**

# %%
print(log_train_total_accuracy)
print(log_train_total_loss) 
print(log_test_total_accuracy)
print(log_test_total_loss)
# Out:
# [12.946, 18.738, 24.546, 30.09, 33.566, 36.452, 38.622, 40.794, 43.51, 45.744, 48.306, 50.288, 52.324, 54.232, 55.386, 57.164, 58.142, 59.506, 60.386, 61.44, 61.992, 61.906, 62.224, 62.052, 62.08, 61.728, 61.624, 61.932, 61.64, 62.084, 61.55, 61.93, 61.93, 61.886, 62.108, 61.746, 61.804, 61.706, 61.854, 61.822, 61.832, 61.608, 61.8, 61.694, 61.672, 61.774, 61.884, 61.958, 61.74, 61.89, 61.598, 61.666, 61.684, 61.848, 61.76, 61.704, 61.902, 61.82, 61.806, 61.974]
# [3814.7059783935547, 846.4653816223145, 783.8247088193893, 728.7373812198639, 698.0003483295441, 671.0692794322968, 649.7142281532288, 626.3825128078461, 602.6293115615845, 580.0362293720245, 557.822108745575, 537.2182970046997, 519.5971615314484, 500.2498313188553, 488.36277812719345, 472.786985874176, 460.52961736917496, 448.50873416662216, 435.07959485054016, 422.94924008846283, 416.4512841105461, 418.08345329761505, 416.7510813474655, 417.29403495788574, 416.05908328294754, 417.6131349205971, 418.64586585760117, 416.57645136117935, 417.0048944950104, 415.0908430814743, 418.3743603825569, 418.1212215423584, 416.71979385614395, 418.16702377796173, 415.8904538154602, 417.67522794008255, 417.9434053301811, 417.7266556620598, 415.57460141181946, 417.37661123275757, 417.2637212276459, 417.7470096349716, 416.6445745229721, 418.29513245821, 416.58850115537643, 417.2478803396225, 416.7397190928459, 416.7211244106293, 418.0885930657387, 416.8575894832611, 417.81531089544296, 419.9363491535187, 417.6301454901695, 417.3701478242874, 415.7026116847992, 418.9279046654701, 415.8134568333626, 416.0751254558563, 416.8609573841095, 416.7900730371475]
# [16.09, 22.04, 30.19, 35.63, 38.16, 38.72, 36.71, 45.8, 48.36, 36.95, 51.01, 48.56, 44.38, 56.54, 53.72, 57.4, 51.38, 55.9, 62.88, 60.94, 63.34, 63.21, 63.22, 63.06, 63.25, 63.19, 62.99, 63.4, 63.06, 63.15, 62.91, 63.09, 63.18, 63.35, 62.98, 63.23, 63.06, 62.96, 62.82, 63.22, 63.37, 62.91, 63.31, 63.19, 63.33, 63.39, 63.04, 62.76, 62.78, 63.33, 63.22, 63.3, 63.21, 63.3, 63.12, 62.91, 63.38, 63.24, 63.41, 63.21]
# [0.023286088109016417, 0.022428098893165587, 0.01993591248989105, 0.017723437762260437, 0.01717396194934845, 0.016645873069763183, 0.017366767477989195, 0.014831097722053528, 0.014236301565170289, 0.019006655287742615, 0.013990921318531037, 0.01488193941116333, 0.017211783349514006, 0.012890874218940735, 0.013439315557479858, 0.013744842028617858, 0.018314416766166686, 0.01260468630194664, 0.010713765335083008, 0.011045042842626572, 0.010364708429574966, 0.010385700261592865, 0.010448437345027924, 0.01053487113714218, 0.010379232239723205, 0.010410187941789627, 0.010497632336616516, 0.01035493631362915, 0.010478342401981354, 0.010522186315059662, 0.010479674690961838, 0.010451725322008132, 0.010400582855939864, 0.010341230612993241, 0.010600510036945343, 0.010405024856328965, 0.010382014948129653, 0.010502970951795578, 0.010628123837709428, 0.01040425699353218, 0.010410763502120971, 0.010481313949823379, 0.010385043644905091, 0.010409798228740693, 0.010348234730958939, 0.010346965545415879, 0.01046446340084076, 0.010497760653495789, 0.010534759175777435, 0.01037506199479103, 0.010414671576023101, 0.010398770302534104, 0.01040395582318306, 0.010361654996871947, 0.010431204742193221, 0.010499510860443114, 0.010355972719192506, 0.010366973978281022, 0.010383375984430314, 0.010440591621398926]

# %% [markdown]
# ###**8. Model Summary**

# %%
from torchsummary import summary

model = resnet50(3, 10)
summary(model.cuda(), (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5            [-1, 256, 8, 8]          16,384
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#         Conv2dAuto-7             [-1, 64, 8, 8]           4,096
#        BatchNorm2d-8             [-1, 64, 8, 8]             128
#               ReLU-9             [-1, 64, 8, 8]               0
#        Conv2dAuto-10             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-11             [-1, 64, 8, 8]             128
#              ReLU-12             [-1, 64, 8, 8]               0
#        Conv2dAuto-13            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-14            [-1, 256, 8, 8]             512
# ResNetBottleNeckBlock-15            [-1, 256, 8, 8]               0
#        Conv2dAuto-16             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-17             [-1, 64, 8, 8]             128
#              ReLU-18             [-1, 64, 8, 8]               0
#        Conv2dAuto-19             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-20             [-1, 64, 8, 8]             128
#              ReLU-21             [-1, 64, 8, 8]               0
#        Conv2dAuto-22            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-23            [-1, 256, 8, 8]             512
# ResNetBottleNeckBlock-24            [-1, 256, 8, 8]               0
#        Conv2dAuto-25             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-26             [-1, 64, 8, 8]             128
#              ReLU-27             [-1, 64, 8, 8]               0
#        Conv2dAuto-28             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-29             [-1, 64, 8, 8]             128
#              ReLU-30             [-1, 64, 8, 8]               0
#        Conv2dAuto-31            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-32            [-1, 256, 8, 8]             512
# ResNetBottleNeckBlock-33            [-1, 256, 8, 8]               0
#       ResNetLayer-34            [-1, 256, 8, 8]               0
#            Conv2d-35            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-36            [-1, 512, 4, 4]           1,024
#        Conv2dAuto-37            [-1, 128, 8, 8]          32,768
#       BatchNorm2d-38            [-1, 128, 8, 8]             256
#              ReLU-39            [-1, 128, 8, 8]               0
#        Conv2dAuto-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#        Conv2dAuto-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-45            [-1, 512, 4, 4]               0
#        Conv2dAuto-46            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-47            [-1, 128, 4, 4]             256
#              ReLU-48            [-1, 128, 4, 4]               0
#        Conv2dAuto-49            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#        Conv2dAuto-52            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-53            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-54            [-1, 512, 4, 4]               0
#        Conv2dAuto-55            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 128, 4, 4]             256
#              ReLU-57            [-1, 128, 4, 4]               0
#        Conv2dAuto-58            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-59            [-1, 128, 4, 4]             256
#              ReLU-60            [-1, 128, 4, 4]               0
#        Conv2dAuto-61            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-62            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-63            [-1, 512, 4, 4]               0
#        Conv2dAuto-64            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-65            [-1, 128, 4, 4]             256
#              ReLU-66            [-1, 128, 4, 4]               0
#        Conv2dAuto-67            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-68            [-1, 128, 4, 4]             256
#              ReLU-69            [-1, 128, 4, 4]               0
#        Conv2dAuto-70            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-71            [-1, 512, 4, 4]           1,024
# ResNetBottleNeckBlock-72            [-1, 512, 4, 4]               0
#       ResNetLayer-73            [-1, 512, 4, 4]               0
#            Conv2d-74           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-75           [-1, 1024, 2, 2]           2,048
#        Conv2dAuto-76            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-77            [-1, 256, 4, 4]             512
#              ReLU-78            [-1, 256, 4, 4]               0
#        Conv2dAuto-79            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-80            [-1, 256, 2, 2]             512
#              ReLU-81            [-1, 256, 2, 2]               0
#        Conv2dAuto-82           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-83           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-84           [-1, 1024, 2, 2]               0
#        Conv2dAuto-85            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-86            [-1, 256, 2, 2]             512
#              ReLU-87            [-1, 256, 2, 2]               0
#        Conv2dAuto-88            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-89            [-1, 256, 2, 2]             512
#              ReLU-90            [-1, 256, 2, 2]               0
#        Conv2dAuto-91           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-92           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-93           [-1, 1024, 2, 2]               0
#        Conv2dAuto-94            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#        Conv2dAuto-97            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-98            [-1, 256, 2, 2]             512
#              ReLU-99            [-1, 256, 2, 2]               0
#       Conv2dAuto-100           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-101           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-102           [-1, 1024, 2, 2]               0
#       Conv2dAuto-103            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-104            [-1, 256, 2, 2]             512
#             ReLU-105            [-1, 256, 2, 2]               0
#       Conv2dAuto-106            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-107            [-1, 256, 2, 2]             512
#             ReLU-108            [-1, 256, 2, 2]               0
#       Conv2dAuto-109           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-110           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-111           [-1, 1024, 2, 2]               0
#       Conv2dAuto-112            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-113            [-1, 256, 2, 2]             512
#             ReLU-114            [-1, 256, 2, 2]               0
#       Conv2dAuto-115            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-116            [-1, 256, 2, 2]             512
#             ReLU-117            [-1, 256, 2, 2]               0
#       Conv2dAuto-118           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-119           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-120           [-1, 1024, 2, 2]               0
#       Conv2dAuto-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#       Conv2dAuto-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#       Conv2dAuto-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
# ResNetBottleNeckBlock-129           [-1, 1024, 2, 2]               0
#      ResNetLayer-130           [-1, 1024, 2, 2]               0
#           Conv2d-131           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-132           [-1, 2048, 1, 1]           4,096
#       Conv2dAuto-133            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-134            [-1, 512, 2, 2]           1,024
#             ReLU-135            [-1, 512, 2, 2]               0
#       Conv2dAuto-136            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-137            [-1, 512, 1, 1]           1,024
#             ReLU-138            [-1, 512, 1, 1]               0
#       Conv2dAuto-139           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-140           [-1, 2048, 1, 1]           4,096
# ResNetBottleNeckBlock-141           [-1, 2048, 1, 1]               0
#       Conv2dAuto-142            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-143            [-1, 512, 1, 1]           1,024
#             ReLU-144            [-1, 512, 1, 1]               0
#       Conv2dAuto-145            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-146            [-1, 512, 1, 1]           1,024
#             ReLU-147            [-1, 512, 1, 1]               0
#       Conv2dAuto-148           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-149           [-1, 2048, 1, 1]           4,096
# ResNetBottleNeckBlock-150           [-1, 2048, 1, 1]               0
#       Conv2dAuto-151            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-152            [-1, 512, 1, 1]           1,024
#             ReLU-153            [-1, 512, 1, 1]               0
#       Conv2dAuto-154            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-155            [-1, 512, 1, 1]           1,024
#             ReLU-156            [-1, 512, 1, 1]               0
#       Conv2dAuto-157           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-158           [-1, 2048, 1, 1]           4,096
# ResNetBottleNeckBlock-159           [-1, 2048, 1, 1]               0
#      ResNetLayer-160           [-1, 2048, 1, 1]               0
#    ResNetEncoder-161           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-162           [-1, 2048, 1, 1]               0
#           Linear-163                   [-1, 10]          20,490
#    ResnetDecoder-164                   [-1, 10]               0
# ================================================================
# Total params: 23,528,522
# Trainable params: 23,528,522
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.25
# Params size (MB): 89.75
# Estimated Total Size (MB): 95.02
# ----------------------------------------------------------------
